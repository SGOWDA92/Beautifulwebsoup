# %% [markdown]
# # WEB SCRAPING-ASSIGNMENT-1

# %% [markdown]
# Submitted by:Sucharitha A M
#              internship batch 16

# %%
# !pip install bs4
# !pip install requests
# Out:
# Requirement already satisfied: bs4 in c:\programdata\anaconda3\lib\site-packages (0.0.1)
# Requirement already satisfied: beautifulsoup4 in c:\programdata\anaconda3\lib\site-packages (from bs4) (4.9.3)
# Requirement already satisfied: soupsieve>1.2; python_version >= "3.0" in c:\programdata\anaconda3\lib\site-packages (from beautifulsoup4->bs4) (2.0.1)
# Requirement already satisfied: requests in c:\programdata\anaconda3\lib\site-packages (2.24.0)
# Requirement already satisfied: idna<3,>=2.5 in c:\programdata\anaconda3\lib\site-packages (from requests) (2.10)
# Requirement already satisfied: chardet<4,>=3.0.2 in c:\programdata\anaconda3\lib\site-packages (from requests) (3.0.4)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in c:\programdata\anaconda3\lib\site-packages (from requests) (1.25.11)
# Requirement already satisfied: certifi>=2017.4.17 in c:\programdata\anaconda3\lib\site-packages (from requests) (2020.6.20)

# %%
# importing the requried libaries
from bs4 import BeautifulSoup
import requests

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (4.6.1)Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 1. Write a python program to display all the header tags from ‘en.wikipedia.org/wiki/Main_Page’.

# %%
from urllib.request import urlopen
from bs4 import BeautifulSoup
html = urlopen('https://en.wikipedia.org/wiki/Main_page')
bs = BeautifulSoup(html,"html.parser")
title = bs.find_all(['h1','h2','h3','h4','h5','h6'])
print('List all the header tags :',*title, sep='\n\n')
# Out:
# List all the header tags :
#
# <h1 class="firstHeading" id="firstHeading">Main Page</h1>
#
# <h2 class="mp-h2" id="mp-tfa-h2"><span id="From_today.27s_featured_article"></span><span class="mw-headline" id="From_today's_featured_article">From today's featured article</span></h2>
#
# <h2 class="mp-h2" id="mp-dyk-h2"><span class="mw-headline" id="Did_you_know_...">Did you know ...</span></h2>
#
# <h2 class="mp-h2" id="mp-itn-h2"><span class="mw-headline" id="In_the_news">In the news</span></h2>
#
# <h2 class="mp-h2" id="mp-otd-h2"><span class="mw-headline" id="On_this_day">On this day</span></h2>
#
# <h2 class="mp-h2" id="mp-tfp-h2"><span id="Today.27s_featured_picture"></span><span class="mw-headline" id="Today's_featured_picture">Today's featured picture</span></h2>
#
# <h2 class="mp-h2" id="mp-other"><span class="mw-headline" id="Other_areas_of_Wikipedia">Other areas of Wikipedia</span></h2>
#
# <h2 class="mp-h2" id="mp-sister"><span id="Wikipedia.27s_sister_projects"></span><span class="mw-headline" id="Wikipedia's_sister_projects">Wikipedia's sister projects</span></h2>
#
# <h2 class="mp-h2" id="mp-lang"><span class="mw-headline" id="Wikipedia_languages">Wikipedia languages</span></h2>
#
# <h2>Navigation menu</h2>
#
# <h3 class="vector-menu-heading" id="p-personal-label">
# <span>Personal tools</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-namespaces-label">
# <span>Namespaces</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-variants-label">
# <span>Variants</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-views-label">
# <span>Views</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-cactions-label">
# <span>More</span>
# </h3>
#
# <h3>
# <label for="searchInput">Search</label>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-navigation-label">
# <span>Navigation</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-interaction-label">
# <span>Contribute</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-tb-label">
# <span>Tools</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-coll-print_export-label">
# <span>Print/export</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-wikibase-otherprojects-label">
# <span>In other projects</span>
# </h3>
#
# <h3 class="vector-menu-heading" id="p-lang-label">
# <span>Languages</span>
# </h3>

# %% [markdown]
# # 2. Write a python program to display IMDB’s Top rated 100 movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame.

# %%
from bs4 import BeautifulSoup
import requests
import re

url = 'http://www.imdb.com/chart/top'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]
imdb = []

for index in range(0, len(movies)):

    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
# Out:
# 1 - The Shawshank Redemption (1994) - Starring: Frank Darabont (dir.), Tim Robbins, Morgan Freeman
# 2 - The Godfather (1972) - Starring: Francis Ford Coppola (dir.), Marlon Brando, Al Pacino
# 3 - The Godfather: Part II (1974) - Starring: Francis Ford Coppola (dir.), Al Pacino, Robert De Niro
# 4 - The Dark Knight (2008) - Starring: Christopher Nolan (dir.), Christian Bale, Heath Ledger
# 5 - 12 Angry Men (1957) - Starring: Sidney Lumet (dir.), Henry Fonda, Lee J. Cobb
# 6 - Schindler's List (1993) - Starring: Steven Spielberg (dir.), Liam Neeson, Ralph Fiennes
# 7 - The Lord of the Rings: The Return of the King (2003) - Starring: Peter Jackson (dir.), Elijah Wood, Viggo Mortensen
# 8 - Pulp Fiction (1994) - Starring: Quentin Tarantino (dir.), John Travolta, Uma Thurman
# 9 - Il buono, il brutto, il cattivo (1966) - Starring: Sergio Leone (dir.), Clint Eastwood, Eli Wallach
# 1 -  The Lord of the Rings: The Fellowship of the Ring (2001) - Starring: Peter Jackson (dir.), Elijah Wood, Ian McKellen
# 247 - Sunrise: A Song of Two Humans (1927) - Starring: F.W. Murnau (dir.), George O'Brien, Janet Gaynor
# 248 - Shin seiki Evangelion Gekijô-ban: Air/Magokoro wo, kimi ni (1997) - Starring: Hideaki Anno (dir.), Megumi Ogata, Megumi Hayashibara
# 249 - The Man Who Shot Liberty Valance (1962) - Starring: John Ford (dir.), James Stewart, John Wayne
# 250 - Le notti di Cabiria (1957) - Starring: Federico Fellini (dir.), Giulietta Masina, François Périer

# %% [markdown]
# # 3. Write a python program to display IMDB’s Top rated 100 Indian movies’ data (i.e. Name, IMDB rating, Year of release) and make data frame.

# %%
from bs4 import BeautifulSoup
import requests
import re

url = 'http://www.imdb.com/india/top-rated-indian-movies/'
response = requests.get(url)
soup = BeautifulSoup(response.text, 'lxml')

movies = soup.select('td.titleColumn')
links = [a.attrs.get('href') for a in soup.select('td.titleColumn a')]
crew = [a.attrs.get('title') for a in soup.select('td.titleColumn a')]
ratings = [b.attrs.get('data-value') for b in soup.select('td.posterColumn span[name=ir]')]
votes = [b.attrs.get('data-value') for b in soup.select('td.ratingColumn strong')]
imdb = []


for index in range(0, len(movies)):
    
    movie_string = movies[index].get_text()
    movie = (' '.join(movie_string.split()).replace('.', ''))
    movie_title = movie[len(str(index))+1:-7]
    year = re.search('\((.*?)\)', movie_string).group(1)
    place = movie[:len(str(index))-(len(movie))]
    data = {"movie_title": movie_title,
            "year": year,
            "place": place,
            "star_cast": crew[index],
            "rating": ratings[index],
            "vote": votes[index],
            "link": links[index]}
    imdb.append(data)

for item in imdb:
    print(item['place'], '-', item['movie_title'], '('+item['year']+') -', 'Starring:', item['star_cast'])
# Out:
# 1 - Pather Panchali (1955) - Starring: Satyajit Ray (dir.), Kanu Bannerjee, Karuna Bannerjee
# 2 - Nayakan (1987) - Starring: Mani Ratnam (dir.), Kamal Haasan, Saranya Ponvannan
# 3 - Pariyerum Perumal (2018) - Starring: Mari Selvaraj (dir.), Kathir, Anandhi
# 4 - Anbe Sivam (2003) - Starring: Sundar C. (dir.), Kamal Haasan, Madhavan
# 5 - Golmaal (1979) - Starring: Hrishikesh Mukherjee (dir.), Amol Palekar, Bindiya Goswami
# 6 - Apur Sansar (1959) - Starring: Satyajit Ray (dir.), Soumitra Chatterjee, Sharmila Tagore
# 7 - C/o Kancharapalem (2018) - Starring: Venkatesh Maha (dir.), Radha Bessy, Subba Rao Vepada
# 8 - Kireedam (1989) - Starring: Sibi Malayil (dir.), Mohanlal, Thilakan
# 9 - Manichitrathazhu (1993) - Starring: Fazil (dir.), Mohanlal, Shobana
# 1 -  Natsamrat (2016) - Starring: Mahesh Manjrekar (dir.), Nana Patekar, Medha Manjrekar
# 11 - Drishyam 2 (2021) - Starring: Jeethu Joseph (dir.), Mohanlal, Meena
# 12 - 96 (2018) - Starring: C. Prem Kumar (dir.), Vijay Sethupathi, Adithya Bhaskar
# 13 - Black Friday (2004) - Starring: Anurag Kashyap (dir.), Kay Kay Menon, Pawan Malhotra
# 14 - Thevar Magan (1992) - Starring: Bharathan (dir.), Kamal Haasan, Shivaji Ganesan
# 247 - Parmanu: The Story of Pokhran (2018) - Starring: Abhishek Sharma (dir.), John Abraham, Boman Irani
# 248 - Delhi Belly (2011) - Starring: Abhinay Deo (dir.), Imran Khan, Vir Das
# 249 - Trapped (2016) - Starring: Vikramaditya Motwane (dir.), Rajkummar Rao, Geetanjali Thapa
# 250 - Stree (2018) - Starring: Amar Kaushik (dir.), Rajkummar Rao, Shraddha Kapoor

# %%
pip install lxml
# Out:
# Requirement already satisfied: lxml in c:\programdata\anaconda3\lib\site-packages (4.6.1)Note: you may need to restart the kernel to use updated packages.

# %% [markdown]
# # 4. Write a python program to scrap book name, author name, genre and book review of any 5 books from ‘www.bookpage.com'.

# %%
import pandas as pd
from bs4 import BeautifulSoup
import requests

page = requests.get('http://bookpage.com/reviews/')
soup = BeautifulSoup(page.content,'html.parser')

url_tags = soup.find_all("div",class_="pagination")
urls = []
for i in url_tags:
    for j in i.find_all("a"):
        urls.append(j['href'])
urls
# Out:
# ['#',
#  '/reviews?page=2',
#  '/reviews?page=3',
#  '#',
#  '/reviews?page=2',
#  '/reviews?page=1000']

# %%
book_name=[]
for url in urls:
    book = requests.get('http://www.bookpage.com'+url)
    soup = BeautifulSoup(book.content,'html.parser')
    name = soup.find_all('h4',class_="italic")
    review = soup.find_all('body')
    author = soup.find_all('head')
    for i in name:
        book_name.append(i.text)
        
book_name
# Out:
# ['\nKatee Robert\n',
#  '\nAccompaniment for LGBTQ+ fellow travelers\n',
#  '\nWe Can’t Keep Meeting Like This\n',
#  '\n ★ The Ride of Her Life\n',
#  '\n ★ The One Hundred Years of Lenni and Margot\n',
#  '\n ★ Golden Girl\n',
#  '\nWith Teeth\n',
#  '\nThe Library of the Dead\n',
#  '\n ★ All Our Hidden Gifts\n',
#  '\n ★ Americanon\n',
#  '\n ★ The Chosen and the Beautiful \n',
#  '\nRez Dogs\n',
#  "\nSomebody's Daughter\n",
#  '\n ★ Four Hundred Souls\n',
#  '\nThe Nature of Witches\n',
#  '\n ★ The Thousand Crimes of Ming Tsu\n',
#  '\n ★ My Place at the Table\n',
#  '\nThe Removed\n',
#  '\n ★ Revival Season\n',
#  '\n ★ The Cot in the Living Room\n',
#  '\nKing Richard\n',
#  '\nHeaven\n',
#  '\nThe Guncle\n',
#  '\nThe Coming Storm\n',
#  '\n ★ Instructions for Dancing\n',
#  '\nSuper Fly\n',
#  '\nClint Smith\n',
#  '\nWhodunit: June 2021\n',
#  '\nWe Can’t Keep Meeting Like This\n',
#  '\n ★ The Ride of Her Life\n',
#  '\n ★ The One Hundred Years of Lenni and Margot\n',
#  '\n ★ Golden Girl\n',
#  '\nWith Teeth\n',
#  '\nThe Library of the Dead\n',
#  '\n ★ All Our Hidden Gifts\n',
#  '\n ★ Americanon\n',
#  '\n ★ The Chosen and the Beautiful \n',
#  '\nRez Dogs\n',
#  "\nSomebody's Daughter\n",
#  '\n ★ Four Hundred Souls\n',
#  '\nThe Nature of Witches\n',
#  '\n ★ The Thousand Crimes of Ming Tsu\n',
#  '\nLeaving Cecil Street\n',
#  '\nCity of Pearl\n',
#  '\nRats\n',
#  '\nBlue Blood\n',
#  '\nA Sundog Moment\n',
#  '\nThose Who Save Us\n',
#  '\nThe Body of David Hayes\n',
#  '\nIslands\n',
#  "\nEurope's Last Summer\n",
#  "\nGeronimo's Bones\n"]

# %% [markdown]
# # 5. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape:

# %%
import sys,requests,csv,io
from bs4 import BeautifulSoup
from urllib.parse import urljoin

url = "http://www.cricbuzz.com/cricket-stats/icc-rankings/batsmen-rankings"
r = requests.get(url)
r.content
soup = BeautifulSoup(r.content, "html.parser")

maindiv = soup.find_all("div", {"class": "text-center"})
for div in maindiv:
    print(div.text)
# Out:
# PositionPlayerRating
#  1       –    Kane Williamson NEW ZEALAND   919
#  2       –    Steven Smith AUSTRALIA   891
#  3       –    Marnus Labuschagne AUSTRALIA   878
#  4       –    Joe Root ENGLAND   831
#  5       –    Virat Kohli INDIA   814
#  6       –    Rishabh Pant INDIA   747
#  7       –    Henry Nicholls NEW ZEALAND   747
#  8       –    Rohit Sharma INDIA   747
#  9       1    David Warner AUSTRALIA   724
#  10       1    Babar Azam PAKISTAN   714
#  11       –    Dimuth Karunaratne SRI LANKA   712
#  12       –    Tom Latham NEW ZEALAND   706
#  13       –    Ben Stokes ENGLAND   705
#  14       –    Cheteshwar Pujara INDIA   697
#  15       –    Ajinkya Rahane INDIA   688
#  16       –    Aiden Markram SOUTH AFRICA   673
#  17       3    Azhar Ali PAKISTAN   673
#  18       1    Ross Taylor NEW ZEALAND   669
#  19       –    Dean Elgar SOUTH AFRICA   662
#  20       2    Mohammad Rizwan PAKISTAN   642
#  21       –    Mushfiqur Rahim BANGLADESH   640
#  22       –    Quinton de Kock SOUTH AFRICA   625
#  23       –    Jos Buttler ENGLAND   620
#  24       –    Travis Head AUSTRALIA   618
#  25       –    Angelo Mathews SRI LANKA   618
#  26       1    Tamim Iqbal BANGLADESH   611
#  27       1    Sean Williams ZIMBABWE   609
#  28       –    BJ Watling NEW ZEALAND   604
#  29       –    Mayank Agarwal INDIA   600
#  30       –    Mominul Haque BANGLADESH   590
#  31       –    Niroshan Dickwella SRI LANKA   589
#  32       –    Dhananjaya de Silva SRI LANKA   588
#  33       –    Faf du Plessis SOUTH AFRICA   582
#  34       –    Asad Shafiq PAKISTAN   572
#  35       –    Brendan Taylor ZIMBABWE   569
#  36       –    Shakib Al Hasan BANGLADESH   567
#  37       –    Colin de Grandhomme NEW ZEALAND   566
#  38       –    Jason Holder WEST INDIES   561
#  39       –    Usman Khawaja AUSTRALIA   561
#  40       38    Abid Ali PAKISTAN   560
#  41       1    Tim Paine AUSTRALIA   555
#  42       1    Ravindra Jadeja INDIA   555
#  43       1    Rory Burns ENGLAND   541
#  44       1    Kraigg Brathwaite WEST INDIES   541
#  45       1    Nkrumah Bonner WEST INDIES   537
#  46       2    Temba Bavuma SOUTH AFRICA   529
#  47       2    Jermaine Blackwood WEST INDIES   529
#  48       3    Sikandar Raza ZIMBABWE   528
#  49       3    Craig Ervine ZIMBABWE   527
import numpy as np
url = "https://www.icc-cricket.com/rankings/mens/team-rankings/odi"
r = requests.get(url)
r.content
soup = BeautifulSoup(r.content, "html.parser")
maindiv = soup.find_all("Team")
maindiv = soup.find_all("Matches")
maindiv = soup.find_all("points")
maindiv = soup.find_all(" ratings")
maindiv = soup.find_all("div", {"class": "text-center"})
maindiv = soup.find_all("table",class_="table ranking table")
maindiv = soup.find_all("div.rankings-block_container")
maindiv = soup.find_all("tbody")
for div in maindiv:
    print(div.text)
df = pd.read_csv('10 ODI.csv')
df.head()
# Out:
# 1
#
#
# New Zealand
# NZ
#
# 17
# 2,054
#
#                             121
#
#
#
#
#
# 2
#
#
# Australia
# AUS
#
# 25
# 2,945
# 118
#
#
# 3
#
#
# India
# IND
#
# 29
# 3,344
# 115
#
#
# 4
#
#
# England
# ENG
#
# 27
# 3,100
# 115
#
#
# 5
#
#
# South Africa
# SA
#
# 20
# 2,137
# 107
#
#
# 6
#
#
# Pakistan
# PAK
#
# 24
# 2,323
# 97
#
#
# 7
#
#
# Bangladesh
# BAN
#
# 27
# 2,438
# 90
#
#
# 8
#
#
# West Indies
# WI
#
# 27
# 2,222
# 82
#
#
# 9
#
#
# Sri Lanka
# SL
#
# 24
# 1,876
# 78
#
#
# 10
#
#
# Afghanistan
# AFG
#
# 17
# 1,054
# 62
#
#
# 11
#
#
# Netherlands
# NED
#
# 5
# 249
# 50
#
#
# 12
#
#
# Ireland
# IRE
#
# 19
# 807
# 42
#
#
# 13
#
#
# Zimbabwe
# ZIM
#
# 15
# 588
# 39
#
#
# 14
#
#
# Scotland
# SCO
#
# 7
# 258
# 37
#
#
# 15
#
#
# Oman
# OMA
#
# 7
# 240
# 34
#
#
# 16
#
#
# Nepal
# NEP
#
# 5
# 119
# 24
#
#
# 17
#
#
# UAE
# UAE
#
# 9
# 190
# 21
#
#
# 18
#
#
# Namibia
# NAM
#
# 6
# 97
# 16
#
#
# 19
#
#
# United States
# USA
#
# 8
# 93
# 12
#
#
# 20
#
#
# Papua New Guinea
# PNG
#
# 5
# 0
# 0
#    pos           Team  Matches  Points  Ratings
# 0    1    New Zealand       10    2054      121
# 1    2      Australia       25    2945      118
# 2    3          India       29    3344      115
# 3    4        England       27    3100      115
# 4    5   South Africa       20    2137      107

# %% [markdown]
# # ii) Top 10 ODI Batsmen in men along with the records of their team and rating.

# %%
url = "https://sports.ndtv.com/cricket/icc-rankings/odi-batting"
r = requests.get(url)
r.content
soup = BeautifulSoup(r.content, "html.parser")
maindiv = soup.find_all("columns")
maindiv = soup.find_all("rank table")
maindiv = soup.find_all("rank text")
maindiv = soup.find_all("carrer Best ratings")
maindiv = soup.find_all("div", {"class": "text-center"})
maindiv = soup.find_all("table",class_="table ranking table")
maindiv = soup.find_all("div.rankings-block_container")
maindiv = soup.find_all("tbody")
for div in maindiv:
    print(div.text)
# Out:
# Rank
# Player
# Rating
# Career Best Rating
#
#
# 1
#
#
#
#
#
#
#
#
# Babar Azam
#
# Pakistan
#
#
# 865
# 865 v South Africa, 07/04/2021
#
#
# 2
#
#
#
#
#
#
#
#
# Virat Kohli
#
# India
#
#
# 857
# 911 v England, 12/07/2018
#
#
# 3
#
#
#
#
#
#
#
#
# Rohit Sharma
#
# India
#
#
# 825
# 885 v Sri Lanka, 06/07/2019
#
#
# 4
#
#
#
#
#
#
#
#
# Ross Taylor
#
# New Zealand
#
#
# 801
# 841 v Bangladesh, 05/06/2019
#
#
# 5
#
#
#
#
#
#
#
#
# Aaron Finch
#
# Australia
#
#
# 791
# 798 v England, 25/06/2019
#
#
# 6
#
#
#
#
#
#
#
#
# Jonny Bairstow
#
# England
#
#
# 785
# 796 v India, 26/03/2021
#
#
# 7
#
#
#
#
#
#
#
#
# Fakhar Zaman
#
# Pakistan
#
#
# 778
# 778 v South Africa, 07/04/2021
#
#
# 7
#
#
#
#
#
#
#
#
# Faf du Plessis
#
# South Africa
#
#
# 778
# 820 v Australia, 06/07/2019
#
#
# 9
#
#
#
#
#
#
#
#
# David Warner
#
# Australia
#
#
# 773
# 880 v Pakistan, 26/01/2017
#
#
# 9
#
#
#
#
#
#
#
#
# Shai Hope
#
# West Indies
#
#
# 773
# 808 v Bangladesh, 17/05/2019
#
#
# 11
#
#
#
#
#
#
#
#
# Quinton de Kock
#
# South Africa
#
#
# 756
# 813 v Sri Lanka, 10/03/2019
#
#
# 12
#
#
#
#
#
#
#
#
# Kane Williamson
#
# New Zealand
#
#
# 754
# 799 v India, 09/07/2019
#
#
# 13
#
#
#
#
#
#
#
#
# Imam-ul-Haq
#
# Pakistan
#
#
# 751
# 768 v South Africa, 02/04/2021
#
#
# 14
#
#
#
#
#
#
#
#
# Mushfiqur Rahim
#
# Bangladesh
#
#
# 739
# 739 v Sri Lanka, 25/05/2021
#
#
# 15
#
#
#
#
#
#
#
#
# Joe Root
#
# England
#
#
# 723
# 824 v Sri Lanka, 13/10/2018
#
#
# 16
#
#
#
#
#
#
#
#
# Martin Guptill
#
# New Zealand
#
#
# 707
# 789 v South Africa, 01/03/2017
#
#
# 16
#
#
#
#
#
#
#
#
# Steven Smith
#
# Australia
#
#
# 707
# 752 v Pakistan, 22/01/2017
#
#
# 18
#
#
#
#
#
#
#
#
# Shikhar Dhawan
#
# India
#
#
# 706
# 813 v Pakistan, 23/09/2018
#
#
# 19
#
#
#
#
#
#
#
#
# Jason Roy
#
# England
#
#
# 689
# 782 v Australia, 11/07/2019
#
#
# 20
#
#
#
#
#
#
#
#
# Paul Stirling
#
# Ireland
#
#
# 684
# 693 v Pakistan, 23/05/2013
#
#
# 20
#
#
#
#
#
#
#
#
# Glenn Maxwell
#
# Australia
#
#
# 684
# 735 v India, 20/01/2016
#
#
# 22
#
#
#
#
#
#
#
#
# Rassie van der Dussen
#
# South Africa
#
#
# 680
# 683 v Pakistan, 04/04/2021
#
#
# 23
#
#
#
#
#
#
#
#
# Usman Khawaja
#
# Australia
#
#
# 675
# 735 v New Zealand, 29/06/2019
#
#
# 24
#
#
#
#
#
#
#
#
# Tamim Iqbal
#
# Bangladesh
#
#
# 674
# 737 v West Indies, 28/07/2018
#
#
# 25
#
#
#
#
#
#
#
#
# Ben Stokes
#
# England
#
#
# 668
# 694 v New Zealand, 14/07/2019
#
#
# 26
#
#
#
#
#
#
#
#
# Eoin Morgan
#
# England
#
#
# 655
# 720 v Afghanistan, 18/06/2019
#
#
# 27
#
#
#
#
#
#
#
#
# KL Rahul
#
# India
#
#
# 646
# 657 v England, 26/03/2021
#
#
# 28
#
#
#
#
#
#
#
#
# Alex Carey
#
# Australia
#
#
# 644
# 644 v India, 02/12/2020
#
#
# 29
#
#
#
#
#
#
#
#
# Shakib Al Hasan
#
# Bangladesh
#
#
# 641
# 692 v Pakistan, 05/07/2019
#
#
# 30
#
#
#
#
#
#
#
#
# David Miller
#
# South Africa
#
#
# 640
# 643 v Pakistan, 04/04/2021
#
#
# 31
#
#
#
#
#
#
#
#
# Shimron Hetmyer
#
# West Indies
#
#
# 633
# 709 v India, 15/12/2019
#
#
# 32
#
#
#
#
#
#
#
#
# Jos Buttler
#
# England
#
#
# 627
# 741 v Bangladesh, 08/06/2019
#
#
# 33
#
#
#
#
#
#
#
#
# Tom Latham
#
# New Zealand
#
#
# 624
# 631 v Bangladesh, 23/03/2021
#
#
# 34
#
#
#
#
#
#
#
#
# Nicholas Pooran
#
# West Indies
#
#
# 614
# 634 v Ireland, 12/01/2020
#
#
# 35
#
#
#
#
#
#
#
#
# Haris Sohail
#
# Pakistan
#
#
# 603
# 618 v Zimbabwe, 30/10/2020
#
#
# 36
#
#
#
#
#
#
#
#
# Henry Nicholls
#
# New Zealand
#
#
# 581
# 596 v Bangladesh, 20/03/2021
#
#
# 37
#
#
#
#
#
#
#
#
# Aqib Ilyas
#
# Oman
#
#
# 578
# 578 v United States, 11/02/2020
#
#
# 38
#
#
#
#
#
#
#
#
# Mahmudullah
#
# Bangladesh
#
#
# 576
# 579 v Afghanistan, 23/09/2018
#
#
# 39
#
#
#
#
#
#
#
#
# Kyle Coetzer
#
# Scotland
#
#
# 573
# 647 v Ireland, 18/03/2018
#
#
# 40
#
#
#
#
#
#
#
#
# Brendan Taylor
#
# Zimbabwe
#
#
# 571
# 667 v New Zealand, 09/02/2012
#
#
# 41
#
#
#
#
#
#
#
#
# Angelo Mathews
#
# Sri Lanka
#
#
# 569
# 707 v England, 07/12/2014
#
#
# 42
#
#
#
#
#
#
#
#
# Hardik Pandya
#
# India
#
#
# 561
# 561 v England, 28/03/2021
#
#
# 42
#
#
#
#
#
#
#
#
# Sean Williams
#
# Zimbabwe
#
#
# 561
# 561 v Pakistan, 03/11/2020
#
#
# 44
#
#
#
#
#
#
#
#
# Kedar Jadhav
#
# India
#
#
# 560
# 629 v Afghanistan, 22/06/2019
#
#
# 45
#
#
#
#
#
#
#
#
# Rahmat Shah
#
# Afghanistan
#
#
# 559
# 625 v Sri Lanka, 17/09/2018
#
#
# 45
#
#
#
#
#
#
#
#
# Evin Lewis
#
# West Indies
#
#
# 559
# 567 v Sri Lanka, 12/03/2021
#
#
# 47
#
#
#
#
#
#
#
#
# Mohammad Hafeez
#
# Pakistan
#
#
# 546
# 665 v Bangladesh, 04/03/2014
#
#
# 48
#
#
#
#
#
#
#
#
# Kusal Mendis
#
# Sri Lanka
#
#
# 544
# 631 v Zimbabwe, 30/06/2017
#
#
# 48
#
#
#
#
#
#
#
#
# Danushka Gunathilaka
#
# Sri Lanka
#
#
# 544
# 546 v West Indies, 14/03/2021
#
#
# 50
#
#
#
#
#
#
#
#
# Liton Das
#
# Bangladesh
#
#
# 538
# 573 v West Indies, 22/01/2021
#
#
# 51
#
#
#
#
#
#
#
#
# Andy Balbirnie
#
# Ireland
#
#
# 537
# 570 v Zimbabwe, 01/07/2019
#
#
# 52
#
#
#
#
#
#
#
#
# Sikandar Raza
#
# Zimbabwe
#
#
# 536
# 576 v Afghanistan, 22/10/2015
#
#
# 53
#
#
#
#
#
#
#
#
# Imad Wasim
#
# Pakistan
#
#
# 533
# 556 v Bangladesh, 05/07/2019
#
#
# 54
#
#
#
#
#
#
#
#
# Soumya Sarkar
#
# Bangladesh
#
#
# 532
# 671 v South Africa, 15/07/2015
#
#
# 55
#
#
#
#
#
#
#
#
# Kusal Perera
#
# Sri Lanka
#
#
# 529
# 553 v Bangladesh, 31/07/2019
#
#
# 56
#
#
#
#
#
#
#
#
# Marcus Stoinis
#
# Australia
#
#
# 525
# 616 v India, 08/03/2019
#
#
# 57
#
#
#
#
#
#
#
#
# Mohammad Shahzad
#
# Afghanistan
#
#
# 519
# 594 v Bangladesh, 28/09/2016
#
#
# 58
#
#
#
#
#
#
#
#
# Sarfaraz Ahmed
#
# Pakistan
#
#
# 512
# 581 v West Indies, 05/10/2016
#
#
# 59
#
#
#
#
#
#
#
#
# Calum MacLeod
#
# Scotland
#
#
# 508
# 585 v England, 10/06/2018
#
#
# 60
#
#
#
#
#
#
#
#
# Colin de Grandhomme
#
# New Zealand
#
#
# 507
# 520 v Pakistan, 19/01/2018
#
#
# 61
#
#
#
#
#
#
#
#
# Marnus Labuschagne
#
# Australia
#
#
# 506
# 532 v India, 29/11/2020
#
#
# 61
#
#
#
#
#
#
#
#
# Najibullah Zadran
#
# Afghanistan
#
#
# 506
# 518 v West Indies, 09/11/2019
#
#
# 63
#
#
#
#
#
#
#
#
# Chris Gayle
#
# West Indies
#
#
# 504
# 804 v Zimbabwe, 30/11/2003
#
#
# 64
#
#
#
#
#
#
#
#
# Hashmatullah Shahidi
#
# Afghanistan
#
#
# 498
# 519 v India, 22/06/2019
#
#
# 65
#
#
#
#
#
#
#
#
# Avishka Fernando
#
# Sri Lanka
#
#
# 497
# 514 v West Indies, 26/02/2020
#
#
# 66
#
#
#
#
#
#
#
#
# Shaun Marsh
#
# Australia
#
#
# 495
# 581 v South Africa, 18/01/2009
#
#
# 66
#
#
#
#
#
#
#
#
# Kevin O'Brien
#
# Ireland
#
#
# 495
# 602 v Netherlands, 07/07/2013
#
#
# 66
#
#
#
#
#
#
#
#
# James Neesham
#
# New Zealand
#
#
# 495
# 549 v Pakistan, 26/06/2019
#
#
# 69
#
#
#
#
#
#
#
#
# Mohammad Nabi
#
# Afghanistan
#
#
# 494
# 545 v Bangladesh, 28/09/2016
#
#
# 70
#
#
#
#
#
#
#
#
# Mitchell Marsh
#
# Australia
#
#
# 486
# 641 v New Zealand, 06/12/2016
#
#
# 71
#
#
#
#
#
#
#
#
# Peter Handscomb
#
# Australia
#
#
# 483
# 593 v Pakistan, 27/03/2019
#
#
# 72
#
#
#
#
#
#
#
#
# Asghar Afghan
#
# Afghanistan
#
#
# 479
# 483 v West Indies, 11/11/2019
#
#
# 72
#
#
#
#
#
#
#
#
# Richie Berrington
#
# Scotland
#
#
# 479
# 487 v United States, 14/12/2019
#
#
# 72
#
#
#
#
#
#
#
#
# Shreyas Iyer
#
# India
#
#
# 479
# 513 v New Zealand, 11/02/2020
#
#
# 75
#
#
#
#
#
#
#
#
# William Porterfield
#
# Ireland
#
#
# 475
# 539 v UAE, 12/03/2018
#
#
# 76
#
#
#
#
#
#
#
#
# Muhammad Usman
#
# United Arab Emirates
#
#
# 471
# 478 v Ireland, 08/01/2021
#
#
# 77
#
#
#
#
#
#
#
#
# Colin Munro
#
# New Zealand
#
#
# 468
# 539 v Sri Lanka, 05/01/2019
#
#
# 78
#
#
#
#
#
#
#
#
# Craig Ervine
#
# Zimbabwe
#
#
# 464
# 524 v Afghanistan, 18/10/2015
#
#
# 79
#
#
#
#
#
#
#
#
# Mitchell Santner
#
# New Zealand
#
#
# 460
# 502 v England, 10/03/2018
#
#
# 80
#
#
#
#
#
#
#
#
# Heinrich Klaasen
#
# South Africa
#
#
# 457
# 499 v Australia, 07/03/2020
#
#
# 81
#
#
#
#
#
#
#
#
# Aiden Markram
#
# South Africa
#
#
# 454
# 459 v New Zealand, 19/06/2019
#
#
# 82
#
#
#
#
#
#
#
#
# Lahiru Thirimanne
#
# Sri Lanka
#
#
# 452
# 599 v West Indies, 04/11/2015
#
#
# 83
#
#
#
#
#
#
#
#
# Andile Phehlukwayo
#
# South Africa
#
#
# 450
# 450 v Pakistan, 07/04/2021
#
#
# 84
#
#
#
#
#
#
#
#
# Jason Holder
#
# West Indies
#
#
# 445
# 445 v Sri Lanka, 14/03/2021
#
#
# 85
#
#
#
#
#
#
#
#
# Temba Bavuma
#
# South Africa
#
#
# 444
# 444 v Pakistan, 07/04/2021
#
#
# 86
#
#
#
#
#
#
#
#
# Assad Vala
#
# Papua New Guinea
#
#
# 443
# 444 v Namibia, 23/09/2019
#
#
# 87
#
#
#
#
#
#
#
#
# Thisara Perera
#
# Sri Lanka
#
#
# 442
# 509 v New Zealand, 08/01/2019
#
#
# 88
#
#
#
#
#
#
#
#
# Ravindra Jadeja
#
# India
#
#
# 440
# 552 v West Indies, 08/10/2014
#
#
# 89
#
#
#
#
#
#
#
#
# Sabbir Rahman
#
# Bangladesh
#
#
# 439
# 515 v Sri Lanka, 19/01/2018
#
#
# 90
#
#
#
#
#
#
#
#
# Mohammad Mithun
#
# Bangladesh
#
#
# 435
# 452 v New Zealand, 23/03/2021
#
#
# 91
#
#
#
#
#
#
#
#
# Rishabh Pant
#
# India
#
#
# 432
# 432 v England, 28/03/2021
#
#
# 91
#
#
#
#
#
#
#
#
# Dinesh Chandimal
#
# Sri Lanka
#
#
# 432
# 667 v Australia, 02/03/2012
#
#
# 91
#
#
#
#
#
#
#
#
# Rashid Khan
#
# Afghanistan
#
#
# 432
# 477 v Ireland, 10/03/2019
#
#
# 94
#
#
#
#
#
#
#
#
# George Munsey
#
# Scotland
#
#
# 430
# 430 v Netherlands, 20/05/2021
#
#
# 95
#
#
#
#
#
#
#
#
# Rovman Powell
#
# West Indies
#
#
# 426
# 456 v India, 24/10/2018
#
#
# 96
#
#
#
#
#
#
#
#
# Dhananjaya de Silva
#
# Sri Lanka
#
#
# 420
# 444 v Bangladesh, 26/07/2019
#
#
# 97
#
#
#
#
#
#
#
#
# Gulbadin Naib
#
# Afghanistan
#
#
# 415
# 440 v Ireland, 28/02/2018
#
#
# 97
#
#
#
#
#
#
#
#
# Tony Ura
#
# Papua New Guinea
#
#
# 415
# 416 v Namibia, 23/09/2019
#
#
# 99
#
#
#
#
#
#
#
#
# Chris Woakes
#
# England
#
#
# 411
# 481 v Australia, 26/01/2018
#
#
# 100
#
#
#
#
#
#
#
#
# Sam Billings
#
# England
#
#
# 409
# 415 v Australia, 16/09/2020

# %% [markdown]
# # iii) Top 10 ODI bowlers along with the records of their team and rating.

# %%
url = "https://sports.ndtv.com/cricket/icc-rankings/odi-bowling"
r = requests.get(url)
r.content
soup = BeautifulSoup(r.content, "html.parser")
maindiv = soup.find_all("columns")
maindiv = soup.find_all("rank table")
maindiv = soup.find_all("rank text")
maindiv = soup.find_all("carrer Best ratings")
maindiv = soup.find_all("div", {"class": "text-center"})
maindiv = soup.find_all("table",class_="table ranking table")
maindiv = soup.find_all("div.rankings-block_container")
maindiv = soup.find_all("tbody")
for div in maindiv:
    print(div.text)
# Out:
# Rank
# Player
# Rating
# Career Best Rating
#
#
# 1
#
#
#
#
#
#
#
#
# Trent Boult
#
# New Zealand
#
#
# 737
# 770 v West Indies, 22/06/2019
#
#
# 2
#
#
#
#
#
#
#
#
# Mahedi Hasan
#
# Bangladesh
#
#
# 725
# 725 v Sri Lanka, 25/05/2021
#
#
# 3
#
#
#
#
#
#
#
#
# Mujeeb Ur Rahman
#
# Afghanistan
#
#
# 708
# 712 v Ireland, 24/01/2021
#
#
# 4
#
#
#
#
#
#
#
#
# Matt Henry
#
# New Zealand
#
#
# 691
# 691 v Bangladesh, 26/03/2021
#
#
# 5
#
#
#
#
#
#
#
#
# Jasprit Bumrah
#
# India
#
#
# 690
# 841 v West Indies, 01/11/2018
#
#
# 6
#
#
#
#
#
#
#
#
# Kagiso Rabada
#
# South Africa
#
#
# 666
# 724 v England, 29/05/2017
#
#
# 7
#
#
#
#
#
#
#
#
# Chris Woakes
#
# England
#
#
# 665
# 676 v New Zealand, 14/07/2019
#
#
# 8
#
#
#
#
#
#
#
#
# Josh Hazlewood
#
# Australia
#
#
# 660
# 733 v England, 26/01/2018
#
#
# 9
#
#
#
#
#
#
#
#
# Mustafizur Rahman
#
# Bangladesh
#
#
# 652
# 695 v West Indies, 14/12/2018
#
#
# 10
#
#
#
#
#
#
#
#
# Pat Cummins
#
# Australia
#
#
# 646
# 729 v Pakistan, 12/06/2019
#
#
# 11
#
#
#
#
#
#
#
#
# Mohammad Amir
#
# Pakistan
#
#
# 638
# 663 v Sri Lanka, 02/10/2019
#
#
# 12
#
#
#
#
#
#
#
#
# Shaheen Afridi
#
# Pakistan
#
#
# 634
# 634 v South Africa, 07/04/2021
#
#
# 13
#
#
#
#
#
#
#
#
# Bhuvneshwar Kumar
#
# India
#
#
# 632
# 657 v West Indies, 17/10/2014
#
#
# 14
#
#
#
#
#
#
#
#
# Jofra Archer
#
# England
#
#
# 627
# 642 v Australia, 13/09/2020
#
#
# 15
#
#
#
#
#
#
#
#
# Rashid Khan
#
# Afghanistan
#
#
# 626
# 806 v Pakistan, 21/09/2018
#
#
# 16
#
#
#
#
#
#
#
#
# Adam Zampa
#
# Australia
#
#
# 623
# 623 v India, 02/12/2020
#
#
# 17
#
#
#
#
#
#
#
#
# Shakib Al Hasan
#
# Bangladesh
#
#
# 619
# 717 v Zimbabwe, 05/11/2009
#
#
# 17
#
#
#
#
#
#
#
#
# Lockie Ferguson
#
# New Zealand
#
#
# 619
# 668 v West Indies, 22/06/2019
#
#
# 19
#
#
#
#
#
#
#
#
# Mitchell Starc
#
# Australia
#
#
# 611
# 783 v New Zealand, 29/03/2015
#
#
# 20
#
#
#
#
#
#
#
#
# Lungi Ngidi
#
# South Africa
#
#
# 606
# 621 v Australia, 04/03/2020
#
#
# 21
#
#
#
#
#
#
#
#
# Akila Dananjaya
#
# Sri Lanka
#
#
# 597
# 651 v England, 23/10/2018
#
#
# 22
#
#
#
#
#
#
#
#
# Mohammad Nabi
#
# Afghanistan
#
#
# 596
# 653 v Zimbabwe, 26/02/2017
#
#
# 23
#
#
#
#
#
#
#
#
# Mark Wood
#
# England
#
#
# 594
# 615 v Sri Lanka, 21/06/2019
#
#
# 24
#
#
#
#
#
#
#
#
# Yuzvendra Chahal
#
# India
#
#
# 584
# 730 v New Zealand, 23/01/2019
#
#
# 25
#
#
#
#
#
#
#
#
# Mitchell Santner
#
# New Zealand
#
#
# 583
# 663 v England, 25/02/2018
#
#
# 26
#
#
#
#
#
#
#
#
# Mohammed Shami
#
# India
#
#
# 574
# 654 v Bangladesh, 19/03/2015
#
#
# 27
#
#
#
#
#
#
#
#
# Alzarri Joseph
#
# West Indies
#
#
# 569
# 569 v Sri Lanka, 14/03/2021
#
#
# 28
#
#
#
#
#
#
#
#
# Kuldeep Yadav
#
# India
#
#
# 564
# 765 v New Zealand, 26/01/2019
#
#
# 29
#
#
#
#
#
#
#
#
# Ravindra Jadeja
#
# India
#
#
# 559
# 738 v Zimbabwe, 01/08/2013
#
#
# 30
#
#
#
#
#
#
#
#
# Sheldon Cottrell
#
# West Indies
#
#
# 558
# 581 v Sri Lanka, 26/02/2020
#
#
# 31
#
#
#
#
#
#
#
#
# Liam Plunkett
#
# England
#
#
# 546
# 646 v West Indies, 29/09/2017
#
#
# 32
#
#
#
#
#
#
#
#
# Andy McBrine
#
# Ireland
#
#
# 536
# 570 v Zimbabwe, 01/07/2019
#
#
# 33
#
#
#
#
#
#
#
#
# Ahmed Raza
#
# United Arab Emirates
#
#
# 531
# 531 v Ireland, 18/01/2021
#
#
# 34
#
#
#
#
#
#
#
#
# Adil Rashid
#
# England
#
#
# 529
# 687 v Sri Lanka, 20/10/2018
#
#
# 35
#
#
#
#
#
#
#
#
# Shadab Khan
#
# Pakistan
#
#
# 523
# 607 v South Africa, 22/01/2019
#
#
# 36
#
#
#
#
#
#
#
#
# Dwaine Pretorius
#
# South Africa
#
#
# 515
# 539 v Australia, 06/07/2019
#
#
# 37
#
#
#
#
#
#
#
#
# Colin de Grandhomme
#
# New Zealand
#
#
# 508
# 522 v India, 11/02/2020
#
#
# 38
#
#
#
#
#
#
#
#
# Andile Phehlukwayo
#
# South Africa
#
#
# 506
# 613 v Pakistan, 30/01/2019
#
#
# 39
#
#
#
#
#
#
#
#
# Tim Southee
#
# New Zealand
#
#
# 500
# 638 v England, 20/02/2015
#
#
# 40
#
#
#
#
#
#
#
#
# Ish Sodhi
#
# New Zealand
#
#
# 496
#
#
#
# 41
#
#
#
#
#
#
#
#
# Imad Wasim
#
# Pakistan
#
#
# 495
# 570 v England, 19/05/2019
#
#
# 42
#
#
#
#
#
#
#
#
# Mark Watt
#
# Scotland
#
#
# 490
# 495 v United States, 14/12/2019
#
#
# 42
#
#
#
#
#
#
#
#
# Tendai Chatara
#
# Zimbabwe
#
#
# 490
# 562 v Ireland, 07/03/2015
#
#
# 44
#
#
#
#
#
#
#
#
# Usman Shinwari
#
# Pakistan
#
#
# 489
# 504 v Sri Lanka, 02/10/2019
#
#
# 45
#
#
#
#
#
#
#
#
# Jhye Richardson
#
# Australia
#
#
# 488
# 548 v Pakistan, 24/03/2019
#
#
# 46
#
#
#
#
#
#
#
#
# Moeen Ali
#
# England
#
#
# 486
# 629 v Australia, 24/06/2018
#
#
# 47
#
#
#
#
#
#
#
#
# Boyd Rankin
#
# Ireland
#
#
# 485
# 592 v England, 16/09/2013
#
#
# 48
#
#
#
#
#
#
#
#
# Mashrafe Mortaza
#
# Bangladesh
#
#
# 478
# 653 v Zimbabwe, 23/01/2009
#
#
# 49
#
#
#
#
#
#
#
#
# Rohan Mustafa
#
# United Arab Emirates
#
#
# 477
# 477 v Ireland, 18/01/2021
#
#
# 50
#
#
#
#
#
#
#
#
# Nuwan Pradeep
#
# Sri Lanka
#
#
# 476
# 506 v England, 13/10/2018
#
#
# 51
#
#
#
#
#
#
#
#
# David Willey
#
# England
#
#
# 475
# 551 v Sri Lanka, 02/07/2016
#
#
# 51
#
#
#
#
#
#
#
#
# Mohammad Saifuddin
#
# Bangladesh
#
#
# 475
# 496 v West Indies, 25/01/2021
#
#
# 53
#
#
#
#
#
#
#
#
# Hasan Ali
#
# Pakistan
#
#
# 473
# 766 v New Zealand, 06/01/2018
#
#
# 54
#
#
#
#
#
#
#
#
# Tabraiz Shamsi
#
# South Africa
#
#
# 470
# 486 v Australia, 04/03/2020
#
#
# 54
#
#
#
#
#
#
#
#
# Nathan Coulter-Nile
#
# Australia
#
#
# 470
# 514 v Bangladesh, 20/06/2019
#
#
# 56
#
#
#
#
#
#
#
#
# Faheem Ashraf
#
# Pakistan
#
#
# 469
# 477 v South Africa, 02/04/2021
#
#
# 57
#
#
#
#
#
#
#
#
# Safyaan Sharif
#
# Scotland
#
#
# 467
# 542 v England, 10/06/2018
#
#
# 58
#
#
#
#
#
#
#
#
# Jason Holder
#
# West Indies
#
#
# 465
# 486 v Sri Lanka, 10/03/2021
#
#
# 59
#
#
#
#
#
#
#
#
# Nathan Lyon
#
# Australia
#
#
# 462
# 510 v South Africa, 06/07/2019
#
#
# 59
#
#
#
#
#
#
#
#
# Chris Morris
#
# South Africa
#
#
# 462
# 507 v Sri Lanka, 03/06/2017
#
#
# 61
#
#
#
#
#
#
#
#
# Dushmantha Chameera
#
# Sri Lanka
#
#
# 459
# 482 v England, 23/10/2018
#
#
# 61
#
#
#
#
#
#
#
#
# Wanindu Hasaranga
#
# Sri Lanka
#
#
# 459
# 459 v Bangladesh, 25/05/2021
#
#
# 63
#
#
#
#
#
#
#
#
# Kyle Jarvis
#
# Zimbabwe
#
#
# 458
# 473 v Ireland, 07/07/2019
#
#
# 63
#
#
#
#
#
#
#
#
# James Neesham
#
# New Zealand
#
#
# 458
# 458 v Bangladesh, 26/03/2021
#
#
# 63
#
#
#
#
#
#
#
#
# Suranga Lakmal
#
# Sri Lanka
#
#
# 458
# 594 v Bangladesh, 25/01/2018
#
#
# 66
#
#
#
#
#
#
#
#
# Wahab Riaz
#
# Pakistan
#
#
# 454
# 522 v England, 13/11/2015
#
#
# 67
#
#
#
#
#
#
#
#
# Junaid Khan
#
# Pakistan
#
#
# 449
# 655 v Sri Lanka, 27/12/2013
#
#
# 68
#
#
#
#
#
#
#
#
# Simi Singh
#
# Ireland
#
#
# 448
# 448 v Afghanistan, 26/01/2021
#
#
# 69
#
#
#
#
#
#
#
#
# Sikandar Raza
#
# Zimbabwe
#
#
# 443
# 494 v UAE, 16/04/2019
#
#
# 70
#
#
#
#
#
#
#
#
# Ben Stokes
#
# England
#
#
# 442
# 474 v New Zealand, 03/07/2019
#
#
# 71
#
#
#
#
#
#
#
#
# Kemar Roach
#
# West Indies
#
#
# 431
# 650 v Pakistan, 19/07/2013
#
#
# 72
#
#
#
#
#
#
#
#
# Josh Davey
#
# Scotland
#
#
# 427
# 436 v UAE, 15/12/2019
#
#
# 72
#
#
#
#
#
#
#
#
# Dawlat Zadran
#
# Afghanistan
#
#
# 427
# 574 v Zimbabwe, 02/01/2016
#
#
# 74
#
#
#
#
#
#
#
#
# Sean Williams
#
# Zimbabwe
#
#
# 426
# 474 v Sri Lanka, 30/06/2017
#
#
# 75
#
#
#
#
#
#
#
#
# Anrich Nortje
#
# South Africa
#
#
# 425
# 427 v Pakistan, 04/04/2021
#
#
# 76
#
#
#
#
#
#
#
#
# Aftab Alam
#
# Afghanistan
#
#
# 422
# 456 v South Africa, 15/06/2019
#
#
# 76
#
#
#
#
#
#
#
#
# Kane Richardson
#
# Australia
#
#
# 422
# 448 v India, 17/01/2020
#
#
# 78
#
#
#
#
#
#
#
#
# Yasir Shah
#
# Pakistan
#
#
# 418
# 487 v Zimbabwe, 20/07/2018
#
#
# 79
#
#
#
#
#
#
#
#
# Shardul Thakur
#
# India
#
#
# 411
# 411 v England, 28/03/2021
#
#
# 80
#
#
#
#
#
#
#
#
# Jason Behrendorff
#
# Australia
#
#
# 410
# 439 v England, 11/07/2019
#
#
# 81
#
#
#
#
#
#
#
#
# Thisara Perera
#
# Sri Lanka
#
#
# 408
# 610 v India, 24/07/2012
#
#
# 81
#
#
#
#
#
#
#
#
# Rubel Hossain
#
# Bangladesh
#
#
# 408
# 514 v Pakistan, 01/12/2011
#
#
# 83
#
#
#
#
#
#
#
#
# Dhananjaya de Silva
#
# Sri Lanka
#
#
# 404
# 412 v Bangladesh, 23/05/2021
#
#
# 84
#
#
#
#
#
#
#
#
# Hardik Pandya
#
# India
#
#
# 403
# 552 v South Africa, 16/02/2018
#
#
# 85
#
#
#
#
#
#
#
#
# George Dockrell
#
# Ireland
#
#
# 401
# 589 v West Indies, 16/02/2015
#
#
# 86
#
#
#
#
#
#
#
#
# Gulbadin Naib
#
# Afghanistan
#
#
# 399
# 472 v Ireland, 21/05/2019
#
#
# 87
#
#
#
#
#
#
#
#
# Barry McCarthy
#
# Ireland
#
#
# 397
# 448 v West Indies, 09/01/2020
#
#
# 88
#
#
#
#
#
#
#
#
# Mitchell Marsh
#
# Australia
#
#
# 395
# 511 v New Zealand, 04/12/2016
#
#
# 89
#
#
#
#
#
#
#
#
# Alasdair Evans
#
# Scotland
#
#
# 394
# 421 v England, 10/06/2018
#
#
# 90
#
#
#
#
#
#
#
#
# Tom Curran
#
# England
#
#
# 391
# 404 v Pakistan, 17/05/2019
#
#
# 91
#
#
#
#
#
#
#
#
# Ashley Nurse
#
# West Indies
#
#
# 388
# 568 v India, 27/10/2018
#
#
# 92
#
#
#
#
#
#
#
#
# Hamid Hassan
#
# Afghanistan
#
#
# 387
# 478 v England, 13/03/2015
#
#
# 92
#
#
#
#
#
#
#
#
# Blessing Muzarabani
#
# Zimbabwe
#
#
# 387
# 387 v Pakistan, 03/11/2020
#
#
# 94
#
#
#
#
#
#
#
#
# Lakshan Sandakan
#
# Sri Lanka
#
#
# 383
# 383 v Bangladesh, 25/05/2021
#
#
# 94
#
#
#
#
#
#
#
#
# Marcus Stoinis
#
# Australia
#
#
# 383
# 426 v England, 25/06/2019
#
#
# 96
#
#
#
#
#
#
#
#
# Taijul Islam
#
# Bangladesh
#
#
# 381
# 397 v Zimbabwe, 06/03/2020
#
#
# 97
#
#
#
#
#
#
#
#
# Ashton Agar
#
# Australia
#
#
# 377
# 377 v India, 02/12/2020
#
#
# 98
#
#
#
#
#
#
#
#
# Mohammad Nawaz
#
# Pakistan
#
#
# 376
# 376 v South Africa, 07/04/2021
#
#
# 99
#
#
#
#
#
#
#
#
# Donald Tiripano
#
# Zimbabwe
#
#
# 373
# 373 v Pakistan, 03/11/2020
#
#
# 100
#
#
#
#
#
#
#
#
# Brad Wheal
#
# Scotland
#
#
# 368
# 385 v Sri Lanka, 21/05/2019

# %% [markdown]
# # 6. Write a python program to scrape cricket rankings from ‘www.icc-cricket.com’. You have to scrape

# %%
import sys,requests,csv,io
from bs4 import BeautifulSoup
from urllib.parse import urljoin

url = "https://www.icc-cricket.com/rankings/womens/overview"
r = requests.get(url)
r.content
soup = BeautifulSoup(r.content, "html.parser")

maindiv = soup.find_all("div", {"class": "text-center"})
for div in maindiv:
    print(div.text)

# %% [markdown]
# # i) Top 10 ODI teams in women’s cricket along with the records for matches, points and rating.

# %%
url = "https://www.icc-cricket.com/rankings/womens/overview"
r = requests.get(url)
r.content
soup = BeautifulSoup(r.content, "html.parser")
maindiv = soup.find_all("columns")
maindiv = soup.find_all("rank table")
maindiv = soup.find_all("rank text")
maindiv = soup.find_all("carrer Best ratings")
maindiv = soup.find_all("div", {"class": "text-center"})
maindiv = soup.find_all("table",class_="table ranking table")
maindiv = soup.find_all("div.rankings-block_container")
maindiv = soup.find_all("tbody")
for div in maindiv:
    print(div.text)
# Out:
#                                 2
#
#
#
#                                 South Africa
#
# 118
#
#
#
#                                 3
#
#
#
#                                 England
#
# 117
#
#
#
#                                 4
#
#
#
#                                 India
#
# 111
#
#
#
#                                 5
#
#
#
#                                 New Zealand
#
# 93
#
#
#
#
#
#                                 2
#
#
#
#                                 England
#
# 284
#
#
#
#                                 3
#
#
#
#                                 India
#
# 267
#
#
#
#                                 4
#
#
#
#                                 New Zealand
#
# 267
#
#
#
#                                 5
#
#
#
#                                 South Africa
#
# 252
#
#
#
#
#
#                                     2
#
#
#
# Lizelle Lee
#
#
#
# SA
#
# 758
#
#
#
#                                     3
#
#
#
# Alyssa Healy
#
#
#
# AUS
#
# 756
#
#
#
#                                     4
#
#
#
# Stafanie Taylor
#
#
#
# WI
#
# 746
#
#
#
#                                     5
#
#
#
# Meg Lanning
#
#
#
# AUS
#
# 723
#
#
#
#
#
#                                     2
#
#
#
# Beth Mooney
#
#
#
# AUS
#
# 744
#
#
#
#                                     3
#
#
#
# Meg Lanning
#
#
#
# AUS
#
# 709
#
#
#
#                                     4
#
#
#
# Smriti Mandhana
#
#
#
# IND
#
# 693
#
#
#
#                                     5
#
#
#
# Alyssa Healy
#
#
#
# AUS
#
# 688
#
#
#
#
#
#                                     2
#
#
#
# Megan Schutt
#
#
#
# AUS
#
# 762
#
#
#
#                                     3
#
#
#
# Marizanne Kapp
#
#
#
# SA
#
# 747
#
#
#
#                                     4
#
#
#
# Shabnim Ismail
#
#
#
# SA
#
# 717
#
#
#
#                                     5
#
#
#
# Jhulan Goswami
#
#
#
# IND
#
# 681
#
#
#
#
#
#                                     2
#
#
#
# Shabnim Ismail
#
#
#
# SA
#
# 763
#
#
#
#                                     3
#
#
#
# Sarah Glenn
#
#
#
# ENG
#
# 755
#
#
#
#                                     4
#
#
#
# Megan Schutt
#
#
#
# AUS
#
# 743
#
#
#
#                                     5
#
#
#
# Jess Jonassen
#
#
#
# AUS
#
# 727
#
#
#
#
#
#
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#
#
#
# Ellyse Perry
#
#
#
# AUS
#
# 418
#
#
#
#                                     3
#
#
#
# Stafanie Taylor
#
#
#
# WI
#
# 410
#
#
#
#                                     4
#
#
#
# Natalie Sciver
#
#
#
# ENG
#
# 349
#
#
#
#                                     5
#
#
#
# Deepti Sharma
#
#
#
# IND
#
# 343
#
#
#
#
#
#                                     2
#
#
#
# Natalie Sciver
#
#
#
# ENG
#
# 353
#
#
#
#                                     3
#
#
#
# Kathryn Bryce
#
#
#
# SCO
#
# 336
#
#
#
#                                     4
#
#
#
# Deepti Sharma
#
#
#
# IND
#
# 304
#
#
#
#                                     5
#
#
#
# Stafanie Taylor
#
#
#
# WI
#
# 302

# %% [markdown]
# # ii) Top 10 women’s ODI players along with the records of their team and rating.

# %%
url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi"
r = requests.get(url)
r.content
soup = BeautifulSoup(r.content, "html.parser")
maindiv = soup.find_all("columns")
maindiv = soup.find_all("players")
maindiv = soup.find_all("Team")
maindiv = soup.find_all(" ratings")
maindiv = soup.find_all("div", {"class": "text-center"})
maindiv = soup.find_all("table",class_="table ranking table")
maindiv = soup.find_all("div.rankings-block_container")
maindiv = soup.find_all("tbody")
for div in maindiv:
    print(div.text)
# Out:
#                                     2
#
#
#
# Lizelle Lee
#
#
#
# SA
#
# 758
#
#
#
#                                     3
#
#
#
# Alyssa Healy
#
#
#
# AUS
#
# 756
#
#
#
#                                     4
#
#
#
# Stafanie Taylor
#
#
#
# WI
#
# 746
#
#
#
#                                     5
#
#
#
# Meg Lanning
#
#
#
# AUS
#
# 723
#
#
#
#                                     6
#
#
#
# Amy Satterthwaite
#
#
#
# NZ
#
# 715
#
#
#
#                                     7
#
#
#
# Smriti Mandhana
#
#
#
# IND
#
# 710
#
#
#
#                                     8
#
#
#
# Mithali Raj
#
#
#
# IND
#
# 709
#
#
#
#                                     9
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#
#
#
# Natalie Sciver
#
#
#
# ENG
#
# 685
#
#
#
#                                     10
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#
#
#
# Laura Wolvaardt
#
#
#
# SA
#
# 683
#
#
#
#
#
#                                     2
#
#
#
# Megan Schutt
#
#
#
# AUS
#
# 762
#
#
#
#                                     3
#
#
#
# Marizanne Kapp
#
#
#
# SA
#
# 747
#
#
#
#                                     4
#
#
#
# Shabnim Ismail
#
#
#
# SA
#
# 717
#
#
#
#                                     5
#
#
#
# Jhulan Goswami
#
#
#
# IND
#
# 681
#
#
#
#                                     6
#
#
#
# Katherine Brunt
#
#
#
# ENG
#
# 655
#
#
#
#                                     7
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#
#
#
# Poonam Yadav
#
#
#
# IND
#
# 641
#
#
#
#                                     8
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#
#
#
# Ayabonga Khaka
#
#
#
# SA
#
# 638
#
#
#
#                                     9
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#
#
#
# Ellyse Perry
#
#
#
# AUS
#
# 616
#
#
#
#                                     10
#
#
#
# Shikha Pandey
#
#
#
# IND
#
# 610
#
#
#
#
#
#
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#
#
#
# Ellyse Perry
#
#
#
# AUS
#
# 418
#
#
#
#                                     3
#
#
#
# Stafanie Taylor
#
#
#
# WI
#
# 410
#
#
#
#                                     4
#
#
#
# Natalie Sciver
#
#
#
# ENG
#
# 349
#
#
#
#                                     5
#
#
#
# Deepti Sharma
#
#
#
# IND
#
# 343
#
#
#
#                                     6
#
#
#
# Jess Jonassen
#
#
#
# AUS
#
# 307
#
#
#
#                                     7
#
#
#
# Ashleigh Gardner
#
#
#
# AUS
#
# 252
#
#
#
#                                     8
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#
#
#
# Dane van Niekerk
#
#
#
# SA
#
# 243
#
#
#
#                                     9
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#
#
#
# Sophie Devine
#
#
#
# NZ
#
# 242
#
#
#
#                                     10
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#
#
#
# Amelia Kerr
#
#
#
# NZ
#
# 236

# %% [markdown]
# # iii) Top 10 women’s ODI all-rounder along with the records of their team and rating.

# %%
url = "https://www.icc-cricket.com/rankings/womens/player-rankings/odi"
r = requests.get(url)
r.content
soup = BeautifulSoup(r.content, "html.parser")
maindiv = soup.find_all("columns")
maindiv = soup.find_all("players")
maindiv = soup.find_all("Team")
maindiv = soup.find_all(" ratings")
maindiv = soup.find_all("div", {"class": "text-center"})
maindiv = soup.find_all("table",class_="widegets-ranking-widegets")
maindiv = soup.find_all("tbody")
for div in maindiv:
    print(div.text)
# Out:
#                                     2
#
#
#
# Lizelle Lee
#
#
#
# SA
#
# 758
#
#
#
#                                     3
#
#
#
# Alyssa Healy
#
#
#
# AUS
#
# 756
#
#
#
#                                     4
#
#
#
# Stafanie Taylor
#
#
#
# WI
#
# 746
#
#
#
#                                     5
#
#
#
# Meg Lanning
#
#
#
# AUS
#
# 723
#
#
#
#                                     6
#
#
#
# Amy Satterthwaite
#
#
#
# NZ
#
# 715
#
#
#
#                                     7
#
#
#
# Smriti Mandhana
#
#
#
# IND
#
# 710
#
#
#
#                                     8
#
#
#
# Mithali Raj
#
#
#
# IND
#
# 709
#
#
#
#                                     9
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#
#
#
# Natalie Sciver
#
#
#
# ENG
#
# 685
#
#
#
#                                     10
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#
#
#
# Laura Wolvaardt
#
#
#
# SA
#
# 683
#
#
#
#
#
#                                     2
#
#
#
# Megan Schutt
#
#
#
# AUS
#
# 762
#
#
#
#                                     3
#
#
#
# Marizanne Kapp
#
#
#
# SA
#
# 747
#
#
#
#                                     4
#
#
#
# Shabnim Ismail
#
#
#
# SA
#
# 717
#
#
#
#                                     5
#
#
#
# Jhulan Goswami
#
#
#
# IND
#
# 681
#
#
#
#                                     6
#
#
#
# Katherine Brunt
#
#
#
# ENG
#
# 655
#
#
#
#                                     7
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#
#
#
# Poonam Yadav
#
#
#
# IND
#
# 641
#
#
#
#                                     8
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#
#
#
# Ayabonga Khaka
#
#
#
# SA
#
# 638
#
#
#
#                                     9
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#
#
#
# Ellyse Perry
#
#
#
# AUS
#
# 616
#
#
#
#                                     10
#
#
#
# Shikha Pandey
#
#
#
# IND
#
# 610
#
#
#
#
#
#
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#
#
#
# Ellyse Perry
#
#
#
# AUS
#
# 418
#
#
#
#                                     3
#
#
#
# Stafanie Taylor
#
#
#
# WI
#
# 410
#
#
#
#                                     4
#
#
#
# Natalie Sciver
#
#
#
# ENG
#
# 349
#
#
#
#                                     5
#
#
#
# Deepti Sharma
#
#
#
# IND
#
# 343
#
#
#
#                                     6
#
#
#
# Jess Jonassen
#
#
#
# AUS
#
# 307
#
#
#
#                                     7
#
#
#
# Ashleigh Gardner
#
#
#
# AUS
#
# 252
#
#
#
#                                     8
#
#
#
#
# This player has moved up in the rankings since the previous rankings update
#
#
#
# Dane van Niekerk
#
#
#
# SA
#
# 243
#
#
#
#                                     9
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#
#
#
# Sophie Devine
#
#
#
# NZ
#
# 242
#
#
#
#                                     10
#
#
#
#
# This player has moved down in the rankings since the previous rankings update
#
#
#
# Amelia Kerr
#
#
#
# NZ
#
# 236

# %% [markdown]
# # 7. Write a python program to scrape details of all the mobile phones under Rs. 20,000 listed on Amazon.in. The scraped data should include Product Name, Price, Image URL and Average Rating.

# %%
from bs4 import BeautifulSoup
import requests
  
File = open("out.csv", "a")
url = "https://www.geeksforgeeks.org/scraping-amazon-product-information-using-beautiful-soup/"  
soup = BeautifulSoup(r.content, "lxml")

# %%
try:
        title = soup.find("span", 
                          attrs={"id": 'Amazon mobile'})
        title_value = title.string
  
        title_string =titile_value
            
except AttributeError:
  
        title_string = "Amazson mobile"
  
        print("product Title = ", title_string)
try:     
        title = soup.find("span",
                       attrs={"id": 'mobile price'})
        title_value = title.string
        title_string = title_value
except  AttributeError:
    
    price = "20000"
    
    print("product price = ",price)
# Out:
# product Title =  Amazson mobile
# product price =  20000

# %%
File.write(f"{title_string},")
# Out:
# 15

# %% [markdown]
# # 8. Write a python program to extract information about the local weather from the National Weather Service website of USA, https://www.weather.gov/ for the city, San Francisco. You need to extract data about 7 dayextended forecast display for the city. The data should include period, short description, temperature and description.

# %%
url = "https://forecast.weather.gov/MapClick.php?lat=37.7772&lon=-122.4168#.YKzUyKgzbIU"
r = requests.get(url)
r.content
soup = BeautifulSoup(r.content, "html.parser")
maindiv = soup.find_all("div",id="current condition")
maindiv = soup.find_all("ul",id="seven-day-forecast-list")
maindiv = soup.find_all("div",id="seven-day-forecast")
for div in maindiv:
    print(div.text)
# Out:
# Extended Forecast for
#
# 	    	    San Francisco CA
#
#
#
#
# Tonight
# CloudyLow: 53 °F
#
# Thursday
# Mostly Cloudythen Sunnyand BreezyHigh: 68 °F
#
# ThursdayNight
# Mostly Clearand Breezythen PartlyCloudyLow: 54 °F
#
# Friday
# Mostly Sunnythen Sunnyand BreezyHigh: 66 °F
#
# FridayNight
# Mostly Clearand Breezythen MostlyClearLow: 52 °F
#
# Saturday
# SunnyHigh: 69 °F
#
# SaturdayNight
# Mostly ClearLow: 52 °F
#
# Sunday
# SunnyHigh: 67 °F
#
# SundayNight
# Mostly ClearLow: 52 °F

# %% [markdown]
# # 9. Write a python program to scrape fresher job listings from ‘https://internshala.com/’. It should include job title, company name, CTC, and apply date.

# %%
page = requests.get("http://internshala.com/fresher-jobs")
page
# Out:
# <Response [200]>

# %%
page.content
# Out:
# b'<!DOCTYPE html>\n<html xmlns="http://www.w3.org/1999/xhtml" xmlns:og="http://ogp.me/ns#" xmlns:fb="https://www.facebook.com/2008/fbml">\n    <head>\n        <meta http-equiv="X-UA-Compatible" content="IE=9" />\n        <meta charset="UTF-8" />\n        <meta name="viewport" content="width=device-width, initial-scale=1.0 user-scalable=0" />\n        <meta property="fb:app_id" content="272234782795210" />\n        <meta property="og:type" content="article" />\n                    <meta property="og:image:width" content="1200" />\n            <meta property="og:image:height" content="630" />\n                    <meta name="twitter:site" content="@Internshala" />\n                    <meta name="twitter:card" content="summary_large_image" />\n        \n        <meta name="twitter:creator" content="@internshala" />\n                <meta name="theme-color" content="#ffffff" />\n        <meta name="msapplication-navbutton-color" content="#ffffff"/>\n        <meta name="format-detection" content="telephone=no"/>\n\n                    <link rel="preload" as="font" href="/static/fonts/Inter.woff2?v=3.11" type="font/woff2"  crossorigin />\n            <link rel="preload" as="font" href="/static/fonts/internshala-icons.woff2?do9z3e" type="font/woff2"  crossorigin />                            <script src="/static/js/includes/common/libraries.2583691470.js" defer=""></script>\n                <link rel="stylesheet" href="https://internshala.com//static/cdn/4.4.1/css/bootstrap.min.css" />\n                        <link rel="icon" href="https://internshala.com//favicon.ico?v=5" />\n            <script type="application/ld+json">\n                {\n                "@context":"http://schema.org",\n                "@type":"Organization",\n                "name":"Internshala",\n                "url":"https://internshala.com/",\n                "sameAs":[\n                "https://www.facebook.com/internshala",\n                "https://instagram.com/internshala/",\n                "https://www.linkedin.com/company/internshala",\n                "https://www.youtube.com/channel/UC97qxGRmPsyfV0Miz7AxU2A"\n                ]\n                }\n            </script>\n            <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">\n    window.onerror = function (error, url, line, col, fullError) {\n        error = fullError || error;\n        store_data(error, line);\n    };\n\n    function store_data(error, line) {\n        error = error.stack || error;\n        var url = window.location.href;\n        var browser = get_browser();\n        var browser_name = browser.name;\n        var browser_version = browser.version;\n        var browser_ua = browser.user_agent;\n        var message = "error=" + error + ". Line:" + line + "&browser=" + browser_name + "&version=" + browser_version + "&url=" + url + "&ua=" + browser_ua;\n        var xhttp = new XMLHttpRequest();\n        xhttp.onreadystatechange = function () {\n            if (this.readyState === 4 && this.status === 200) {\n\n            }\n        };\n        xhttp.open("POST", "/browser_error/insert_browser_logs", true);\n        xhttp.setRequestHeader(\'X-Requested-With\', \'XMLHttpRequest\');\n        xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");\n        xhttp.send(message);\n    }\n\n    function get_browser() {\n        var ua = navigator.userAgent, tem, M = ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\\/))\\/?\\s*(\\d+)/i) || [];\n        if (/trident/i.test(M[1])) {\n            tem = /\\brv[ :]+(\\d+)/g.exec(ua) || [];\n            return {name: \'IE\', version: (tem[1] || \'\')};\n        }\n        if (M[1] === \'Chrome\') {\n            tem = ua.match(/\\bOPR|Edge\\/(\\d+)/)\n            if (tem != null) {\n                return {name: \'Opera\', version: tem[1]};\n            }\n        }\n        M = M[2] ? [M[1], M[2]] : [navigator.appName, navigator.appVersion, \'-?\'];\n        if ((tem = ua.match(/version\\/(\\d+)/i)) != null) {\n            ...

# %%
soup=BeautifulSoup(page.content)
soup
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
# <head>
# <meta content="IE=9" http-equiv="X-UA-Compatible"/>
# <meta charset="utf-8"/>
# <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
# <meta content="272234782795210" property="fb:app_id"/>
# <meta content="article" property="og:type"/>
# <meta content="1200" property="og:image:width"/>
# <meta content="630" property="og:image:height"/>
# <meta content="@Internshala" name="twitter:site"/>
# <meta content="summary_large_image" name="twitter:card"/>
# <meta content="@internshala" name="twitter:creator"/>
# <meta content="#ffffff" name="theme-color"/>
# <meta content="#ffffff" name="msapplication-navbutton-color"/>
# <meta content="telephone=no" name="format-detection"/>
# <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" rel="preload" type="font/woff2"/>
# <link as="font" crossorigin="" href="/static/fonts/internshala-icons.woff2?do9z3e" rel="preload" type="font/woff2"/> <script defer="" src="/static/js/includes/common/libraries.2583691470.js"></script>
# <link href="https://internshala.com//static/cdn/4.4.1/css/bootstrap.min.css" rel="stylesheet"/>
# <link href="https://internshala.com//favicon.ico?v=5" rel="icon"/>
# <script type="application/ld+json">
#                 {
#                 "@context":"http://schema.org",
#                 "@type":"Organization",
#                 "name":"Internshala",
#                 "url":"https://internshala.com/",
#                 "sameAs":[
#                 "https://www.facebook.com/internshala",
#                 "https://instagram.com/internshala/",
#                 "https://www.linkedin.com/company/internshala",
#                 "https://www.youtube.com/channel/UC97qxGRmPsyfV0Miz7AxU2A"
#                 ]
#                 }
#             </script>
# <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#     window.onerror = function (error, url, line, col, fullError) {
#         error = fullError || error;
#         store_data(error, line);
#     };
#
#     function store_data(error, line) {
#         error = error.stack || error;
#         var url = window.location.href;
#         var browser = get_browser();
#         var browser_name = browser.name;
#         var browser_version = browser.version;
#         var browser_ua = browser.user_agent;
#         var message = "error=" + error + ". Line:" + line + "&browser=" + browser_name + "&version=" + browser_version + "&url=" + url + "&ua=" + browser_ua;
#         var xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = function () {
#             if (this.readyState === 4 && this.status === 200) {
#
#             }
#         };
#         xhttp.open("POST", "/browser_error/insert_browser_logs", true);
#         xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         xhttp.send(message);
#     }
#
#     function get_browser() {
#         var ua = navigator.userAgent, tem, M = ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\/))\/?\s*(\d+)/i) || [];
#         if (/trident/i.test(M[1])) {
#             tem = /\brv[ :]+(\d+)/g.exec(ua) || [];
#             return {name: 'IE', version: (tem[1] || '')};
#         }
#         if (M[1] === 'Chrome') {
#             tem = ua.match(/\bOPR|Edge\/(\d+)/)
#             if (tem != null) {
#                 return {name: 'Opera', version: tem[1]};
#             }
#         }
#         M = M[2] ? [M[1], M[2]] : [navigator.appName, navigator.appVersion, '-?'];
#         if ((tem = ua.match(/version\/(\d+)/i)) != null) {
#             M.splice(1, 1, tem[1]);
#         }
#         return {
#             name: M[0],
#             version: M[1],
#             user_agent: ua
#         };
#     }
# </script>
# <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#                 var os_type = "";
#                 var browser_name = '';
#                 var is_android = 0;
#                 var is_mobile = 1;
#                 var l_cookie = "";
#                 var view = "internship/search/search";
#                 var mainRole = "guest";
#                 var to_show_account_activated_message = false;
#                 var to_show_subscription_activated_message = false;
#                 var location_autocomplete_min_length = 3;
#                 var new_design_system = true;
#                 var fresherJobsMinCtc = 3;
#                 var show_maintenance_ribbon = false;
#                 var maintenance_ribbon_message = "";
#                 var base_url = 'https://internshala.com/';
#             </script>
# <title>Jobs for freshers | Fresher jobs | Minimum ₹3 LPA jobs</title>
# <meta content="Get latest jobs for freshers and remote jobs and earn CTC of ₹3 LPA+ in all job vacancies. Apply now for free on Internshala." name="description"/>
# <meta content="Jobs for freshers | Fresher jobs | Minimum ₹3 LPA jobs" property="og:title"/>
# <meta content="Get latest jobs for freshers and remote jobs and earn CTC of ₹3 LPA+ in all job vacancies. Apply now for free on Internshala." property="og:description"/>
# <meta content="https://internshala.com//static/images/internshala_og_image.jpg" property="og:image"/>
# <meta content="Jobs for freshers | Fresher jobs | Minimum ₹3 LPA jobs" name="twitter:title"/>
# <meta content="Get latest jobs for freshers and remote jobs and earn CTC of ₹3 LPA+ in all job vacancies. Apply now for free on Internshala." name="twitter:description"/>
# <meta content="https://internshala.com//static/images/internshala_og_image.jpg" property="twitter:image:src"/>
# <link href="/static/css/internship/search/search.1622466380.css" rel="stylesheet" type="text/css"/>
# <script defer="" src="/static/js/combined/common_form.1622630060.js" type="text/javascript"></script>
# <script defer="" src="/static/js/combined/internship-search.1622466380.js" type="text/javascript"></script>
# <script defer="" src="/static/js/subscribe/popup.1622466380.js" type="text/javascript"></script>
# <link href="/fresher-jobs/page-2" rel="next"/>
# <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#         var isMobile = '1';
#     </script>
# <!-- Google Tag Manager -->
# <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-5NSPHG');</script>
# <!-- End Google Tag Manager -->
# <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
# //    window.addEventListener('load', function() {
# //        store_session_data();
# //    });
#
# //    window.addEventListener('DOMContentLoaded', function() {
# //        store_session_data();
# //    });
#
#     var pdcVersion = "0";
#     var toMakeInitialRequest = 1;
#     if (toMakeInitialRequest == 1) {
#         store_session_data();
#     } else  {
#         store_pagespeed_session_data();
#     }
#
#     function store_session_data() {
#         var message = "device=" + getDeviceType();
#         var xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = function () {
#             if (this.readyState === 4 && this.status === 200) {
#                 //Success
#                 var responseText = this.responseText;
#                 try {
#                     data = JSON.parse(responseText);
#                     if (data.success) {
#                         if(data.toMakeUpdateRequest) {
#                             update_session_data();
#                         }
#                     } else {
#                         //TODO
#                     }
#                 } catch (e) {
#                     throw_error(e);
#                 }
#             }
#         };
#
#         xhttp.open("POST", "/info/storeData", true);
#         xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         xhttp.send(message);
#     }
#
#     function store_pagespeed_session_data() {
#         if (view === 'campaign_generic/index') return;
#         var message = "device=" + getDeviceType();
#         var xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = function () {
#             if (this.readyState === 4 && this.status === 200) {
#                 //Success
#                 var responseText = this.responseText;
#                 try {
#                     data = JSON.parse(responseText);
#                     if (data.success) {
#                     } else {
#                         //TODO
#                     }
#                 } catch (e) {
#                     throw_error(e);
#                 }
#             }
#         };
#
#         xhttp.open("POST", "/info/storePageSpeedData", true);
#         xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         xhttp.send(message);
#     }
#
#     function update_session_data() {
#         var message = "";
#         var xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = function () {
#             if (this.readyState === 4 && this.status === 200) {
#                 //Success
#             }
#         };
#
#         xhttp.open("POST", "/info/updateDeviceCookieDomain", true);
#         xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         xhttp.send(message);
#     }
#
#     function getDeviceType() {
#         var device;
#         if (typeof isMobile !== 'undefined') {
#             if (isMobile === '1') {
#                 device = "mobile";
#             } else {
#                 device = "desktop";
#             }
#         } else {
#             device = "NA";
#         }
#
#         return device;
#     }
#
# </script>
# <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
# </script>
# </head>
# <body>
# <!-- Google Tag Manager (noscript) -->
# <noscript><iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5NSPHG" style="display:none;visibility:hidden" width="0"></iframe></noscript>
# <!-- End Google Tag Manager (noscript) --> <div id="wrapper">
# <!-- ribbon -->
# <div class="notification" id="error">
# </div>
# <div class="notification notification_general" id="general_notification" style="display: none">
# </div>
# <!-- modal - error message -->
# <div class="modal fade in internshala-modal" id="error_modal" style="display: none">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-body">
# <div class="image_container error_image">
# <img src="/static/images/common/modal_error.svg"/>
# </div>
# <div class="message_container">
# <div class="text-heading heading_4_5 small-device-text-center"></div>
# <div class="text-message body-main small-device-text-center"></div>
# <div class="button_container">
# <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">Close</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- modal - success message -->
# <div class="modal fade in internshala-modal" id="success_modal" style="display: none">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-body">
# <div class="image_container success_image">
# <img src="/static/images/common/modal_success.svg"/>
# </div>
# <div class="message_container">
# <div class="text-heading heading_4_5 small-device-text-center"></div>
# <div class="text-message body-main small-device-text-center"></div>
# <div class="button_container">
# <button class="btn btn-secondary modal_secondary_btn close_action" data-dismiss="modal">Cancel</button>
# <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">Close</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- modal - success message -->
# <div class="modal fade in internshala-modal" id="success_modal_dual_button" style="display: none">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-body">
# <div class="image_container success_image">
# <img src="/static/images/common/modal_success.svg"/>
# </div>
# <div class="message_container">
# <div class="text-heading heading_4_5 small-device-text-center"></div>
# <div class="text-message body-main small-device-text-center"></div>
# <div class="button_container">
# <a class="btn btn-secondary modal_secondary_btn close_action" data-dismiss="modal">Close</a>
# <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">Close</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!-- modal - alert message -->
# <div class="modal fade in internshala-modal" id="alert_modal" style="display: none">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-body">
# <div class="image_container alert_image">
# <img src="/static/images/common/modal_alert.svg"/>
# </div>
# <div class="message_container">
# <div class="text-heading heading_4_5 small-device-text-center"></div>
# <div class="text-message body-main small-device-text-center"></div>
# <div class="button_container">
# <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">Close</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <!--- confirmation modal-->
# <div class="modal fade in internshala-modal confirmation_modal" id="confirmation_modal" style="display: none">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-body">
# <div class="message_container">
# <div class="text-heading heading_4_5"></div>
# <div class="text-message body-main"></div>
# <div class="button_container">
# <button class="btn btn-secondary modal_secondary_btn close_action" data-dismiss="modal">Cancel</button>
# <a class="btn btn-primary modal_primary_btn yes-button close_action" data-dismiss="modal">Yes</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="loading_image">
# </div>
# <div class="nav_dropdown_backdrop">
# </div>
# <noscript>
# <div class="notification notification_js_disabled" style="display: block;">
#         Oops, your browser does not support Javascript. Please use Internshala in another browser.
#     </div>
# </noscript>
# <div class="toast internshala-toast loading_toast" id="loading_toast" style="display: none;">
# <div class="toast-body-container">
# <div class="toast-body heading_6_6">
#             Loading, please wait...
#         </div>
# </div>
# </div>
# <div class="toast internshala-toast general_toast" style="display: none;">
# <div class="toast-body-container">
# <div class="toast-body heading_6_6">
# </div>
# </div>
# </div>
# <div class="toast internshala-toast error_toast" style="display: none;">
# <div class="toast-body-container">
# <div class="toast-body heading_6_6">
# </div>
# </div>
# </div>
# <div class="toast internshala-toast black_bottom_toast" style="display: none;">
# <div class="toast-body-container">
# <div class="toast-body body-main">
# </div>
# </div>
# </div>
# <div class="popover_overlay">
# </div>
# <div class="chat_notification_loading_image" style="display: none;">
# </div>
# <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal" id="login-modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="modal-header">
# <button class="close" data-dismiss="modal" type="button">
# <i aria-hidden="true" class="ic-24-cross"></i>
# </button>
# </div>
# <div class="modal-body">
# <div id="user-menu-container">
# <div id="user-menu">
# <div class="row">
# <div class="col-xs-6 col-6 user-menu-item active login_student" id="modal_student">
#                                         Student
#                                     </div>
# <div class="col-xs-6 col-6 user-menu-item login_employer" id="modal_employer">
#                                         Employer / T&amp;P
#                                     </div>
# </div>
# </div>
# </div>
# <a class="google_login" href="/login/get_google">
# <div id="google-button-container">
# <div class="google_image_container">
# <img src="/static/images/login/google_logo.png"/>
# </div>
# <div class="google_content">
#                                     Login with Google
#                                 </div>
# </div>
# </a>
# <div class="helper">
# <div class="text2"><p>OR</p></div>
# <div class="border"></div>
# </div>
# <form id="modal-login-form" method="POST" role="form">
# <input name="csrf_test_name" type="hidden" value="ae7eaf671ac5047017257c08a92739db"/>
# <div class="form-group">
# <label class="control-label" for="email">Email</label>
# <input class="form-control" id="modal_email" name="email" placeholder="john@example.com" tabindex="1" type="email"/>
# </div>
# <div class="form-group">
# <label class="control-label" for="password">Password</label>
# <input class="form-control" id="modal_password" name="password" placeholder="Must be atleast 6 characters" tabindex="2" type="password"/>
# </div>
# <div class="forgot_password">
# <a href="/login/forgot_password" id="forgot-password">Forgot password?</a>
# </div>
# <div class="form-group">
# <button class="btn btn-primary" id="modal_login_submit" tabindex="3" type="submit">Login</button>
# </div>
# <div class="form-group new_to_internshala">
# <label>
#                                     New to Internshala? Register (<a href="/registration/student">Student</a> / <a href="/registration/employer">Company</a>)
#                                 </label>
# </div>
# </form>
# </div>
# </div>
# </div>
# </div>
# <!-- Login modal - error message for employers blocked -->
# <div aria-hidden="true" class="modal fade" id="employer_blocked_error_modal" role="dialog" tabindex="-1">
# <div class="modal-dialog">
# <div class="modal-content">
# <div class="heading">
#                     Your account is put on hold.<i aria-hidden="true" class="ic-24-cross" data-dismiss="modal" id="close_modal" style="cursor: pointer;float:right"></i>
# </div>
# <div class="heading1">
#                     Your account is put on hold.<i aria-hidden="true" class="ic-24-cross" data-dismiss="modal" id="close_modal1" style="cursor: pointer;float:right"></i>
# </div>
# <div class="main_content">
# <div class="line1"></div>
# <div class="sub_heading">
#                         What happened?
#                     </div>
# <div>
#                         We have determined that this account is violation of Internshala's <span class="primary_color"><a href="https://internshala.com/terms">rules</a></span>.
#                     </div>
# <div class="content_specially_for">
#                         Specifically for,
#                     </div>
# <div class="error_heading" id="heading_content1"></div>
# <div class="error_content_1" id="error_content1"></div>
# <div class="error_heading" id="heading_content2"></div>
# <div class="error_content_1" id="error_content2"></div>
# <div class="error_content_2">
#                         If you wish to appeal this, or seek further clarification, please contact our team at <span class="primary_color"><a href="mailto:complaints@internshala.com">complaints@internshala.com</a></span>
# </div>
# <div class="line2"></div>
# <div class="icon_container">
# <i class="ic-24-alert-circle"></i>
# <div class="icon_content">
#                             If this has happened by mistake, it will automatically be reverted within 24 hours.
#                         </div>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div class="header_container container-fluid" id="header">
# <div class="max-width-container">
# <div class="layer"></div>
# <div class="sidenav" id="mySidenav">
# <div class="ham_menu_items_container guest">
# <div class="ham_menu_items">
# <div class="ham_main_heading"><a href="/internships">Internships</a></div>
# </div>
# <div class="ham_menu_training_items ham_menu_items without_link">
# <div class="ham_title ham_main_heading">
#                     Online Trainings                                            <div class="contest">
#                             CONTEST                        </div>
# <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_submenu_items">
# <div class="ham_menu_training_items ham_inner_menu_items">
# <div class="ham_inner_title">
#                                     Contests                                                                            <div class="contest">
#                                             ENDS SOON                                        </div>
# <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_inner_submenu_items">
# <a class="trainings_link" href="https://trainings.internshala.com/contest/webdev-battle?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Web Development                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/marketing-ninja?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Digital Marketing                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/python-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Programming with Python                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/autocad-designer-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                AutoCAD                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/machine-learning-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Machine Learning                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/appathon?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Android App Development                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/data-science-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Data Science                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/c-c-plus-coding-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Programming with C &amp; C++                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/finance-wizard-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Financial Modeling and Valuation                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/hackathon?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Ethical Hacking                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/code-java-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Core Java                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/creative-writing-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                Creative Writing                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/solidworks-designer-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                SOLIDWORKS                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/contest/bonjour-french?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#                                                French                                                                                       </a>
# </div>
# </div>
# <div class="ham_menu_training_items ham_inner_menu_items">
# <div class="ham_inner_title">
#                                     Programming                                                                        <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_inner_submenu_items">
# <a class="trainings_link" href="https://trainings.internshala.com/react-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                React                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/blockchain-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Blockchain                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/angular-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Angular                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/r-programming-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                R Programming                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/git-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Git &amp; GitHub                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/how-to-ace-coding-interviews-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                How to Ace Coding Interviews                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/data-structures-algorithms?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Data Structures &amp; Algorithms                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/sas-programming?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                SAS Programming                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/matlab-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                MATLAB                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/software-testing-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Software Testing                                                                                       </a>
# </div>
# </div>
# <div class="ham_menu_training_items ham_inner_menu_items">
# <div class="ham_inner_title">
#                                     Business &amp; Management                                                                        <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_inner_submenu_items">
# <a class="trainings_link" href="https://trainings.internshala.com/excel-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Advanced Excel                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/business-communication-skills-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Business Communication Skills                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/trading-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Beginner's Trading Certification                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/how-to-startup-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                How To Startup                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/tally?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Tally                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/hr?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Human Resource Management                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/sql-data-analytics-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                SQL for Data Analytics                                                                                       </a>
# </div>
# </div>
# <div class="ham_menu_training_items ham_inner_menu_items">
# <div class="ham_inner_title">
#                                     Core Engineering                                                                        <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_inner_submenu_items">
# <a class="trainings_link" href="https://trainings.internshala.com/autocad-three-d-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Autocad 3D                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/advanced-solidworks?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Advanced SOLIDWORKS                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/staad-pro-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                STAAD Pro                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/fusion-360-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Fusion 360                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/iot-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Internet of Things                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/ansys?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Ansys                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/three-d-printing?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                3D Printing                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/pcb-design?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                PCB Design                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/labview?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                LabVIEW                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/arduino?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Arduino                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/catia?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                CATIA                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/matlab-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                MATLAB                                                                                       </a>
# </div>
# </div>
# <div class="ham_menu_training_items ham_inner_menu_items">
# <div class="ham_inner_title">
#                                     Data Science                                                                        <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_inner_submenu_items">
# <a class="trainings_link" href="https://trainings.internshala.com/tableau-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Tableau                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/deep-learning?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Deep Learning                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/sas-programming?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                SAS Programming                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/statistics-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Statistics for Data Science                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/power-bi-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Power BI                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/sql-data-analytics-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                SQL for Data Analytics                                                                                       </a>
# </div>
# </div>
# <div class="ham_menu_training_items ham_inner_menu_items">
# <div class="ham_inner_title">
#                                     Design                                                                        <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_inner_submenu_items">
# <a class="trainings_link" href="https://trainings.internshala.com/graphic-design-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Graphic Design                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/ui-ux-design-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                UI/UX Design                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/video-editing-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Video Editing                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/animation-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Animation                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/wordpress?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                WordPress                                                                                       </a>
# </div>
# </div>
# <div class="ham_menu_training_items ham_inner_menu_items">
# <div class="ham_inner_title">
#                                     Creative Arts                                                                        <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_inner_submenu_items">
# <a class="trainings_link" href="https://trainings.internshala.com/guitar-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Learn Guitar in 30 days                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/photography-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Photography                                                                                       </a>
# </div>
# </div>
# <div class="ham_menu_training_items ham_inner_menu_items">
# <div class="ham_inner_title">
#                                     Career Development                                                                        <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_inner_submenu_items">
# <a class="trainings_link" href="https://trainings.internshala.com/business-communication-skills-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Business Communication Skills                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/ppt-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Internship &amp; Job Preparation                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/how-to-ace-coding-interviews-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                How to Ace Coding Interviews                                                                                       </a>
# </div>
# </div>
# <div class="ham_menu_training_items ham_inner_menu_items">
# <div class="ham_inner_title">
#                                     Architecture                                                                        <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_inner_submenu_items">
# <a class="trainings_link" href="https://trainings.internshala.com/autocad-three-d-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Autocad 3D                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/revit-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Revit                                                                                       </a>
# </div>
# </div>
# <div class="ham_menu_training_items ham_inner_menu_items">
# <div class="ham_inner_title">
#                                     Specializations                                                                        <i class="ic-24-chevron-down"></i>
# </div>
# <div class="ham_inner_submenu_items">
# <a class="trainings_link" href="https://trainings.internshala.com/job-specialization-digital-marketing?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Digital Marketing Specialization                                                                                       </a>
# <a class="trainings_link" href="https://trainings.internshala.com/job-specialization-data-science?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#                                                Data Science Specialization                                                                                       </a>
# </div>
# </div>
# </div>
# </div>
# <div class="ham_menu_items">
# <div class="ham_main_heading"><a href="/internships/work-from-home-jobs?utm_source=wfh_mobile_hamburger">WFH Internships</a></div>
# </div>
# <div class="ham_menu_items">
# <div class="ham_main_heading"><a href="/fresher-jobs">Fresher Jobs</a></div>
# </div>
# <div class="ham_menu_items">
# <div class="ham_main_heading"><a href="/contact">Contact Us</a></div>
# </div>
# <hr class="ham_line_break"/>
# <div class="ham_menu_items">
# <div class="ham_main_heading"><a href="/registration/student">Register - As a Student</a></div>
# </div>
# <div class="ham_menu_items">
# <div class="ham_main_heading"><a href="/registration/employer">Register - As an Employer</a></div>
# </div>
# <div class="ham_menu_items without_link">
# <div class="ham_main_heading home_page_login_button" data-target="#login-modal" data-toggle="modal" id="ham_login_button">Login
#                     </div>
# </div>
# </div>
# </div>
# <nav class="navbar navbar-expand-md">
# <div class="brand_container">
# <img id="hamburger_menu_key" src="/static/images/icons/hamburger-menu-key-new.svg"/>
# <span class="offer_hamburger_dot" id="offer_hamburger_dot"></span>
# <a class="navbar-brand" href="/">
# <img src="/static/images/common/new_internshala_logo.svg"/>
# </a>
# </div> <div class="collapse navbar-collapse navbar_desktop">
# <ul class="navbar-nav nav_menu_container">
# <li class="nav-item internship_container_hover dropdown dropdown-hover dropdown_backdrop">
# <a class="nav-link dropdown-toggle" href="/internships" id="internships_new_superscript">Internships
#         <i class="is_icon_header ic-24-filled-down-arrow"></i>
# </a>
# <div class="dropdown-menu dropdown-menu-center menu_dropdown guest_dropdown" id="internships-dropdown">
# <div class="dropdown-inner">
# <div class="dropdown-inner-container">
# <div class="inner-dropdown">
# <div class="menu-heading">
#                             Location                        </div>
# <ul class="dropdown-menu-part">
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/work-from-home-jobs" style="">Work from Home</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-bangalore" style="">Internship in Bangalore</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-delhi" style="">Internship in Delhi</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-hyderabad" style="">Internship in Hyderabad</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-mumbai" style="">Internship in Mumbai</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-chennai" style="">Internship in Chennai</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-pune" style="">Internship in Pune</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-kolkata" style="">Internship in Kolkata</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-jaipur" style="">Internship in Jaipur</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/international-internship" style="">International Internship</a>
# </li>
# </ul>
# </div>
# <div class="inner-dropdown">
# <div class="menu-heading">
#                             Profile                        </div>
# <ul class="dropdown-menu-part">
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/computer%20science-internship" style="">Computer Science Internship</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/marketing-internship" style="">Marketing Internship</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/finance-internship" style="">Finance Internship</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/mechanical-internship" style="">Mechanical Internship</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/hr-internship" style="">HR Internship</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/digital marketing-internship" style="">Digital Marketing Internship</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/electronics-internship" style="">Electronics Internship</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/content%20writing-internship" style="">Content Writing Internship</a>
# </li>
# <li class="item">
# <a class="item_link internship_item_location" href="https://internshala.com/internships/civil-internship" style="">Civil Internship</a>
# </li>
# ...
#         input_domains.push("g.mail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaiil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.coom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.xom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmali.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaip.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("g-mail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comm");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaul.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmqil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gma.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("g.mail");
#         valid_domains.push("gmail.com");
#         input_domains.push("googlemail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gimal.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.vom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gimail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaio.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaik.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaol.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmailm.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gemail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.in");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.coml");
#         valid_domains.push("gmail.com");
#         input_domains.push("gail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.cm");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmsil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.clm");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmill.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gami.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.ocm");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmain.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmiail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comn");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.ckm");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comcom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gamil.co");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.com.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmai8l.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gamil.comm");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.ckn");
#         valid_domains.push("gmail.com");
#         input_domains.push("g-mail.come");
#         valid_domains.push("gmail.com");
#         input_domains.push("gimeil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("g.mali.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comb");
#         valid_domains.push("gmail.com");
#         input_domains.push("ggmail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.combus");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comch");
#         valid_domains.push("gmail.com");
#         input_domains.push("gma2il.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gimel.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmai.lcom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.come");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmalil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comk");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmeil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.cin");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comlll");
#         valid_domains.push("gmail.com");
#         input_domains.push("gml.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comlo");
#         valid_domains.push("gmail.com");
#         input_domains.push("ghmail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.commaniraj");
#         valid_domains.push("gmail.com");
#         input_domains.push("gimal.co");
#         valid_domains.push("gmail.com");
#         input_domains.push("gamile.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaaail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comopp");
#         valid_domains.push("gmail.com");
#         input_domains.push("gemil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comp");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmajl.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.compin");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaigmai.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comrith");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmamil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comt");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comw");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.cam");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comy");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmial.come");
#         valid_domains.push("gmail.com");
#         input_domains.push("gani.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmile.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.cpm");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmit.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.gom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmmail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.lcom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.clom");
#         valid_domains.push("gmail.com");
#         input_domains.push("g.mail.co");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.om");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.co.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.v.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gamil.come");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.coma");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.coman");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comar");
#         valid_domains.push("gmail.com");
#     var utm_medium = "";
#     var utm_campaign = "";
#     var internship_cluster_size = 5;
#     var internship_type = "";
#     var toShowMatchingPreferences = 0;
#     var searchUIType = "new";
#     var is_ifw_partner_banner_shown = 0;
#     var scroll_from_id = 0;
#     var scroll_page_number = 2;
#     var scroll_last_page = false;
#     var employment_type = "job";
# </script>
# <div class="generic_footer" id="footer">
# <div class="container-fluid">
# <div class="max-width-container">
# <div class="footer_container">
# <div class="footer-column d-none d-lg-block">
# <div class="footer-list">
# <h5>Internships by places</h5>
# <div class="footer-list-item">
# <a href="/internships">Internship in India</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/internship-in-delhi">Internship in Delhi</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/internship-in-bangalore">Internship in Bangalore</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/internship-in-hyderabad">Internship in Hyderabad</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/internship-in-mumbai">Internship in Mumbai</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/internship-in-chennai">Internship in Chennai</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/internship-in-gurgaon">Internship in Gurgaon</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/internship-in-kolkata">Internship in Kolkata</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/work-from-home-jobs">Virtual internship</a>
# </div>
# </div>
# </div>
# <div class="footer-column d-none d-lg-block" id="stream-container">
# <div class="footer-list">
# <h5>Internship by Stream</h5>
# <div class="footer-list-item">
# <a href="/internships/computer%20science-internship">Computer Science Internship</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/electronics-internship">Electronics Internship</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/mechanical-internship">Mechanical Internship</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/civil-internship">Civil Internship</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/marketing-internship">Marketing Internship</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/chemical-internship">Chemical Internship</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/finance-internship">Finance Internship</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/summer%20research%20fellowship-internship">Summer Research Fellowship</a>
# </div>
# <div class="footer-list-item">
# <a href="/internships/campus%20ambassador-internship?utm_medium=footer">Campus Ambassador Program</a>
# </div>
# </div>
# </div>
# <div class="footer-column d-none d-lg-block" id="trainings-container">
# <div class="footer-list">
# <h5>
# <div id="trainings-footer">
# <a href="https://trainings.internshala.com/?utm_source=is-footer-FTUD" rel="noopener" target="_blank">Online Trainings                                                                            <span class="offer">CONTEST</span>
# </a>
# </div>
# </h5>
# <div class="footer-list-item">
# <a href="https://trainings.internshala.com/contest/webdev-battle?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">Web Development</a>
# </div>
# <div class="footer-list-item">
# <a href="https://trainings.internshala.com/contest/appathon?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">Android App Development</a>
# </div>
# <div class="footer-list-item">
# <a href="https://trainings.internshala.com/contest/python-challenge?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">Programming with Python</a>
# </div>
# <div class="footer-list-item">
# <a href="https://trainings.internshala.com/contest/data-science-challenge?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">Data Science</a>
# </div>
# <div class="footer-list-item">
# <a href="https://trainings.internshala.com/contest/hackathon?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">Ethical Hacking</a>
# </div>
# <div class="footer-list-item">
# <a href="https://trainings.internshala.com/contest/code-java-challenge?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">Core Java</a>
# </div>
# <div class="footer-list-item">
# <a href="https://trainings.internshala.com/contest/marketing-ninja?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">Digital Marketing</a>
# </div>
# <div class="footer-list-item">
# <a href="https://trainings.internshala.com/excel-training?utm_source=is-footer-FTUD" rel="noopener" target="_blank">Advanced Excel</a>
# </div>
# <div class="footer-list-item">
# <a href="https://trainings.internshala.com/contest/c-c-plus-coding-challenge?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">Programming with C &amp; C++</a>
# </div>
# </div>
# </div>
# <div class="footer-column" id="about-us-container">
# <div class="footer-list">
# <h5 class="d-none d-lg-block">About Internshala</h5>
# <div id="about_internshala_left">
# <div class="footer-list-item">
# <a href="/about_us">About us</a>
# </div>
# <div class="footer-list-item">
# <a href="/careers">We're hiring</a>
# </div>
# <div class="footer-list-item">
# <a href="/registration/employer?utm_source=ISfooter">Hire interns for your company</a>
# </div>
# <div class="footer-list-item">
# <a href="http://blog.internshala.com/internshala-editorials/team-diary/" target="_blank">Team Diary</a>
# </div>
# <div class="footer-list-item">
# <a href="https://blog.internshala.com/?utm_source=IS_footer" target="_blank">Blog</a>
# </div>
# <div class="footer-list-item">
# <a href="/products_services">Our Services</a>
# </div>
# </div>
# <div id="about_internshala_right">
# <div class="footer-list-item">
# <a href="/terms">Terms &amp; Conditions</a>
# </div>
# <div class="footer-list-item">
# <a href="/privacy">Privacy</a>
# </div>
# <div class="footer-list-item">
# <a href="/contact">Contact us</a>
# </div>
# </div>
# </div>
# </div>
# </div>
# <div id="footer-bottom">
# <a href="https://play.google.com/store/apps/details?id=com.internshala.app&amp;referrer=utm_source%3Dplay_footer" target="_blank">
# <div class="footer-list-item" id="android_app_container">
# <i class="ic-24-playstore"></i> <span>Get Android App</span>
# </div>
# </a>
# <div id="social_media_container">
# <a class="social_media_link_footer" href="https://www.instagram.com/internshala/?utm_source=IS_footer" target="_blank"><i class="ic-24-instagram"></i></a>
# <a class="social_media_link_footer" href="https://twitter.com/Internshala?utm_source=IS_footer" target="_blank"><i class="ic-24-twitter"></i></a>
# <a class="social_media_link_footer" href="https://www.youtube.com/c/internshalaofficial?utm_source=IS_footer" target="_blank"><img class="img-icon" src="/static/images/common/yt_icon_mono_dark.png"/></a>
# <a class="social_media_link_footer" href="https://www.linkedin.com/company/internshala/?utm_source=is-footer" target="_blank"><i class="ic-24-linkedin"></i></a>
# </div>
# <div class="" id="copyright">
#                     © Copyright 2021 Internshala
#                 </div>
# <div class="clear">
# </div>
# </div>
# </div>
# </div>
# </div>
# <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">var big_brand = 'yes';</script> </div>
# <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#     /* <![CDATA[ */
#     var google_conversion_id = 981478532;
#     var google_custom_params = window.google_tag_params;
#     var google_remarketing_only = true;
#     /* ]]> */
# </script>
# <script src="https://www.googleadservices.com/pagead/conversion.js" type="text/javascript">
# </script>
# <noscript>
# <div style="display:inline;">
# <img alt="" height="1" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/981478532/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
# </div>
# </noscript>
# </body>
# <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#         if (new_design_system) {
#             setTimeout(function () {
#                 var loading_toast = document.getElementById("loading_toast");
#                 if (typeof loading_toast !== 'undefined' && loading_toast) {
#                     loading_toast.style.display = "block";
#                 }
#             }, 2000);
#         }
#     </script>
# </html>

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html xmlns="http://www.w3.org/1999/xhtml" xmlns:fb="https://www.facebook.com/2008/fbml" xmlns:og="http://ogp.me/ns#">
#  <head>
#   <meta content="IE=9" http-equiv="X-UA-Compatible"/>
#   <meta charset="utf-8"/>
#   <meta content="width=device-width, initial-scale=1.0 user-scalable=0" name="viewport"/>
#   <meta content="272234782795210" property="fb:app_id"/>
#   <meta content="article" property="og:type"/>
#   <meta content="1200" property="og:image:width"/>
#   <meta content="630" property="og:image:height"/>
#   <meta content="@Internshala" name="twitter:site"/>
#   <meta content="summary_large_image" name="twitter:card"/>
#   <meta content="@internshala" name="twitter:creator"/>
#   <meta content="#ffffff" name="theme-color"/>
#   <meta content="#ffffff" name="msapplication-navbutton-color"/>
#   <meta content="telephone=no" name="format-detection"/>
#   <link as="font" crossorigin="" href="/static/fonts/Inter.woff2?v=3.11" rel="preload" type="font/woff2"/>
#   <link as="font" crossorigin="" href="/static/fonts/internshala-icons.woff2?do9z3e" rel="preload" type="font/woff2"/>
#   <script defer="" src="/static/js/includes/common/libraries.2583691470.js">
#   </script>
#   <link href="https://internshala.com//static/cdn/4.4.1/css/bootstrap.min.css" rel="stylesheet"/>
#   <link href="https://internshala.com//favicon.ico?v=5" rel="icon"/>
#   <script type="application/ld+json">
#    {
#                 "@context":"http://schema.org",
#                 "@type":"Organization",
#                 "name":"Internshala",
#                 "url":"https://internshala.com/",
#                 "sameAs":[
#                 "https://www.facebook.com/internshala",
#                 "https://instagram.com/internshala/",
#                 "https://www.linkedin.com/company/internshala",
#                 "https://www.youtube.com/channel/UC97qxGRmPsyfV0Miz7AxU2A"
#                 ]
#                 }
#   </script>
#   <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#    window.onerror = function (error, url, line, col, fullError) {
#         error = fullError || error;
#         store_data(error, line);
#     };
#
#     function store_data(error, line) {
#         error = error.stack || error;
#         var url = window.location.href;
#         var browser = get_browser();
#         var browser_name = browser.name;
#         var browser_version = browser.version;
#         var browser_ua = browser.user_agent;
#         var message = "error=" + error + ". Line:" + line + "&browser=" + browser_name + "&version=" + browser_version + "&url=" + url + "&ua=" + browser_ua;
#         var xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = function () {
#             if (this.readyState === 4 && this.status === 200) {
#
#             }
#         };
#         xhttp.open("POST", "/browser_error/insert_browser_logs", true);
#         xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         xhttp.send(message);
#     }
#
#     function get_browser() {
#         var ua = navigator.userAgent, tem, M = ua.match(/(opera|chrome|safari|firefox|msie|trident(?=\/))\/?\s*(\d+)/i) || [];
#         if (/trident/i.test(M[1])) {
#             tem = /\brv[ :]+(\d+)/g.exec(ua) || [];
#             return {name: 'IE', version: (tem[1] || '')};
#         }
#         if (M[1] === 'Chrome') {
#             tem = ua.match(/\bOPR|Edge\/(\d+)/)
#             if (tem != null) {
#                 return {name: 'Opera', version: tem[1]};
#             }
#         }
#         M = M[2] ? [M[1], M[2]] : [navigator.appName, navigator.appVersion, '-?'];
#         if ((tem = ua.match(/version\/(\d+)/i)) != null) {
#             M.splice(1, 1, tem[1]);
#         }
#         return {
#             name: M[0],
#             version: M[1],
#             user_agent: ua
#         };
#     }
#   </script>
#   <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#    var os_type = "";
#                 var browser_name = '';
#                 var is_android = 0;
#                 var is_mobile = 1;
#                 var l_cookie = "";
#                 var view = "internship/search/search";
#                 var mainRole = "guest";
#                 var to_show_account_activated_message = false;
#                 var to_show_subscription_activated_message = false;
#                 var location_autocomplete_min_length = 3;
#                 var new_design_system = true;
#                 var fresherJobsMinCtc = 3;
#                 var show_maintenance_ribbon = false;
#                 var maintenance_ribbon_message = "";
#                 var base_url = 'https://internshala.com/';
#   </script>
#   <title>
#    Jobs for freshers | Fresher jobs | Minimum ₹3 LPA jobs
#   </title>
#   <meta content="Get latest jobs for freshers and remote jobs and earn CTC of ₹3 LPA+ in all job vacancies. Apply now for free on Internshala." name="description"/>
#   <meta content="Jobs for freshers | Fresher jobs | Minimum ₹3 LPA jobs" property="og:title"/>
#   <meta content="Get latest jobs for freshers and remote jobs and earn CTC of ₹3 LPA+ in all job vacancies. Apply now for free on Internshala." property="og:description"/>
#   <meta content="https://internshala.com//static/images/internshala_og_image.jpg" property="og:image"/>
#   <meta content="Jobs for freshers | Fresher jobs | Minimum ₹3 LPA jobs" name="twitter:title"/>
#   <meta content="Get latest jobs for freshers and remote jobs and earn CTC of ₹3 LPA+ in all job vacancies. Apply now for free on Internshala." name="twitter:description"/>
#   <meta content="https://internshala.com//static/images/internshala_og_image.jpg" property="twitter:image:src"/>
#   <link href="/static/css/internship/search/search.1622466380.css" rel="stylesheet" type="text/css"/>
#   <script defer="" src="/static/js/combined/common_form.1622630060.js" type="text/javascript">
#   </script>
#   <script defer="" src="/static/js/combined/internship-search.1622466380.js" type="text/javascript">
#   </script>
#   <script defer="" src="/static/js/subscribe/popup.1622466380.js" type="text/javascript">
#   </script>
#   <link href="/fresher-jobs/page-2" rel="next"/>
#   <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#    var isMobile = '1';
#   </script>
#   <!-- Google Tag Manager -->
#   <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#    (function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
# new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
# j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
# 'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
# })(window,document,'script','dataLayer','GTM-5NSPHG');
#   </script>
#   <!-- End Google Tag Manager -->
#   <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#    //    window.addEventListener('load', function() {
# //        store_session_data();
# //    });
#
# //    window.addEventListener('DOMContentLoaded', function() {
# //        store_session_data();
# //    });
#
#     var pdcVersion = "0";
#     var toMakeInitialRequest = 1;
#     if (toMakeInitialRequest == 1) {
#         store_session_data();
#     } else  {
#         store_pagespeed_session_data();
#     }
#
#     function store_session_data() {
#         var message = "device=" + getDeviceType();
#         var xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = function () {
#             if (this.readyState === 4 && this.status === 200) {
#                 //Success
#                 var responseText = this.responseText;
#                 try {
#                     data = JSON.parse(responseText);
#                     if (data.success) {
#                         if(data.toMakeUpdateRequest) {
#                             update_session_data();
#                         }
#                     } else {
#                         //TODO
#                     }
#                 } catch (e) {
#                     throw_error(e);
#                 }
#             }
#         };
#
#         xhttp.open("POST", "/info/storeData", true);
#         xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         xhttp.send(message);
#     }
#
#     function store_pagespeed_session_data() {
#         if (view === 'campaign_generic/index') return;
#         var message = "device=" + getDeviceType();
#         var xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = function () {
#             if (this.readyState === 4 && this.status === 200) {
#                 //Success
#                 var responseText = this.responseText;
#                 try {
#                     data = JSON.parse(responseText);
#                     if (data.success) {
#                     } else {
#                         //TODO
#                     }
#                 } catch (e) {
#                     throw_error(e);
#                 }
#             }
#         };
#
#         xhttp.open("POST", "/info/storePageSpeedData", true);
#         xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         xhttp.send(message);
#     }
#
#     function update_session_data() {
#         var message = "";
#         var xhttp = new XMLHttpRequest();
#         xhttp.onreadystatechange = function () {
#             if (this.readyState === 4 && this.status === 200) {
#                 //Success
#             }
#         };
#
#         xhttp.open("POST", "/info/updateDeviceCookieDomain", true);
#         xhttp.setRequestHeader('X-Requested-With', 'XMLHttpRequest');
#         xhttp.setRequestHeader("Content-type", "application/x-www-form-urlencoded");
#         xhttp.send(message);
#     }
#
#     function getDeviceType() {
#         var device;
#         if (typeof isMobile !== 'undefined') {
#             if (isMobile === '1') {
#                 device = "mobile";
#             } else {
#                 device = "desktop";
#             }
#         } else {
#             device = "NA";
#         }
#
#         return device;
#     }
#   </script>
#   <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#   </script>
#  </head>
#  <body>
#   <!-- Google Tag Manager (noscript) -->
#   <noscript>
#    <iframe height="0" src="https://www.googletagmanager.com/ns.html?id=GTM-5NSPHG" style="display:none;visibility:hidden" width="0">
#    </iframe>
#   </noscript>
#   <!-- End Google Tag Manager (noscript) -->
#   <div id="wrapper">
#    <!-- ribbon -->
#    <div class="notification" id="error">
#    </div>
#    <div class="notification notification_general" id="general_notification" style="display: none">
#    </div>
#    <!-- modal - error message -->
#    <div class="modal fade in internshala-modal" id="error_modal" style="display: none">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-body">
#        <div class="image_container error_image">
#         <img src="/static/images/common/modal_error.svg"/>
#        </div>
#        <div class="message_container">
#         <div class="text-heading heading_4_5 small-device-text-center">
#         </div>
#         <div class="text-message body-main small-device-text-center">
#         </div>
#         <div class="button_container">
#          <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">
#           Close
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- modal - success message -->
#    <div class="modal fade in internshala-modal" id="success_modal" style="display: none">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-body">
#        <div class="image_container success_image">
#         <img src="/static/images/common/modal_success.svg"/>
#        </div>
#        <div class="message_container">
#         <div class="text-heading heading_4_5 small-device-text-center">
#         </div>
#         <div class="text-message body-main small-device-text-center">
#         </div>
#         <div class="button_container">
#          <button class="btn btn-secondary modal_secondary_btn close_action" data-dismiss="modal">
#           Cancel
#          </button>
#          <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">
#           Close
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- modal - success message -->
#    <div class="modal fade in internshala-modal" id="success_modal_dual_button" style="display: none">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-body">
#        <div class="image_container success_image">
#         <img src="/static/images/common/modal_success.svg"/>
#        </div>
#        <div class="message_container">
#         <div class="text-heading heading_4_5 small-device-text-center">
#         </div>
#         <div class="text-message body-main small-device-text-center">
#         </div>
#         <div class="button_container">
#          <a class="btn btn-secondary modal_secondary_btn close_action" data-dismiss="modal">
#           Close
#          </a>
#          <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">
#           Close
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- modal - alert message -->
#    <div class="modal fade in internshala-modal" id="alert_modal" style="display: none">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-body">
#        <div class="image_container alert_image">
#         <img src="/static/images/common/modal_alert.svg"/>
#        </div>
#        <div class="message_container">
#         <div class="text-heading heading_4_5 small-device-text-center">
#         </div>
#         <div class="text-message body-main small-device-text-center">
#         </div>
#         <div class="button_container">
#          <a class="btn btn-primary modal_primary_btn close_action" data-dismiss="modal">
#           Close
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!--- confirmation modal-->
#    <div class="modal fade in internshala-modal confirmation_modal" id="confirmation_modal" style="display: none">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-body">
#        <div class="message_container">
#         <div class="text-heading heading_4_5">
#         </div>
#         <div class="text-message body-main">
#         </div>
#         <div class="button_container">
#          <button class="btn btn-secondary modal_secondary_btn close_action" data-dismiss="modal">
#           Cancel
#          </button>
#          <a class="btn btn-primary modal_primary_btn yes-button close_action" data-dismiss="modal">
#           Yes
#          </a>
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="loading_image">
#    </div>
#    <div class="nav_dropdown_backdrop">
#    </div>
#    <noscript>
#     <div class="notification notification_js_disabled" style="display: block;">
#      Oops, your browser does not support Javascript. Please use Internshala in another browser.
#     </div>
#    </noscript>
#    <div class="toast internshala-toast loading_toast" id="loading_toast" style="display: none;">
#     <div class="toast-body-container">
#      <div class="toast-body heading_6_6">
#       Loading, please wait...
#      </div>
#     </div>
#    </div>
#    <div class="toast internshala-toast general_toast" style="display: none;">
#     <div class="toast-body-container">
#      <div class="toast-body heading_6_6">
#      </div>
#     </div>
#    </div>
#    <div class="toast internshala-toast error_toast" style="display: none;">
#     <div class="toast-body-container">
#      <div class="toast-body heading_6_6">
#      </div>
#     </div>
#    </div>
#    <div class="toast internshala-toast black_bottom_toast" style="display: none;">
#     <div class="toast-body-container">
#      <div class="toast-body body-main">
#      </div>
#     </div>
#    </div>
#    <div class="popover_overlay">
#    </div>
#    <div class="chat_notification_loading_image" style="display: none;">
#    </div>
#    <div aria-hidden="true" aria-labelledby="myModalLabel" class="modal" id="login-modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="modal-header">
#        <button class="close" data-dismiss="modal" type="button">
#         <i aria-hidden="true" class="ic-24-cross">
#         </i>
#        </button>
#       </div>
#       <div class="modal-body">
#        <div id="user-menu-container">
#         <div id="user-menu">
#          <div class="row">
#           <div class="col-xs-6 col-6 user-menu-item active login_student" id="modal_student">
#            Student
#           </div>
#           <div class="col-xs-6 col-6 user-menu-item login_employer" id="modal_employer">
#            Employer / T&amp;P
#           </div>
#          </div>
#         </div>
#        </div>
#        <a class="google_login" href="/login/get_google">
#         <div id="google-button-container">
#          <div class="google_image_container">
#           <img src="/static/images/login/google_logo.png"/>
#          </div>
#          <div class="google_content">
#           Login with Google
#          </div>
#         </div>
#        </a>
#        <div class="helper">
#         <div class="text2">
#          <p>
#           OR
#          </p>
#         </div>
#         <div class="border">
#         </div>
#        </div>
#        <form id="modal-login-form" method="POST" role="form">
#         <input name="csrf_test_name" type="hidden" value="ae7eaf671ac5047017257c08a92739db"/>
#         <div class="form-group">
#          <label class="control-label" for="email">
#           Email
#          </label>
#          <input class="form-control" id="modal_email" name="email" placeholder="john@example.com" tabindex="1" type="email"/>
#         </div>
#         <div class="form-group">
#          <label class="control-label" for="password">
#           Password
#          </label>
#          <input class="form-control" id="modal_password" name="password" placeholder="Must be atleast 6 characters" tabindex="2" type="password"/>
#         </div>
#         <div class="forgot_password">
#          <a href="/login/forgot_password" id="forgot-password">
#           Forgot password?
#          </a>
#         </div>
#         <div class="form-group">
#          <button class="btn btn-primary" id="modal_login_submit" tabindex="3" type="submit">
#           Login
#          </button>
#         </div>
#         <div class="form-group new_to_internshala">
#          <label>
#           New to Internshala? Register (
#           <a href="/registration/student">
#            Student
#           </a>
#           /
#           <a href="/registration/employer">
#            Company
#           </a>
#           )
#          </label>
#         </div>
#        </form>
#       </div>
#      </div>
#     </div>
#    </div>
#    <!-- Login modal - error message for employers blocked -->
#    <div aria-hidden="true" class="modal fade" id="employer_blocked_error_modal" role="dialog" tabindex="-1">
#     <div class="modal-dialog">
#      <div class="modal-content">
#       <div class="heading">
#        Your account is put on hold.
#        <i aria-hidden="true" class="ic-24-cross" data-dismiss="modal" id="close_modal" style="cursor: pointer;float:right">
#        </i>
#       </div>
#       <div class="heading1">
#        Your account is put on hold.
#        <i aria-hidden="true" class="ic-24-cross" data-dismiss="modal" id="close_modal1" style="cursor: pointer;float:right">
#        </i>
#       </div>
#       <div class="main_content">
#        <div class="line1">
#        </div>
#        <div class="sub_heading">
#         What happened?
#        </div>
#        <div>
#         We have determined that this account is violation of Internshala's
#         <span class="primary_color">
#          <a href="https://internshala.com/terms">
#           rules
#          </a>
#         </span>
#         .
#        </div>
#        <div class="content_specially_for">
#         Specifically for,
#        </div>
#        <div class="error_heading" id="heading_content1">
#        </div>
#        <div class="error_content_1" id="error_content1">
#        </div>
#        <div class="error_heading" id="heading_content2">
#        </div>
#        <div class="error_content_1" id="error_content2">
#        </div>
#        <div class="error_content_2">
#         If you wish to appeal this, or seek further clarification, please contact our team at
#         <span class="primary_color">
#          <a href="mailto:complaints@internshala.com">
#           complaints@internshala.com
#          </a>
#         </span>
#        </div>
#        <div class="line2">
#        </div>
#        <div class="icon_container">
#         <i class="ic-24-alert-circle">
#         </i>
#         <div class="icon_content">
#          If this has happened by mistake, it will automatically be reverted within 24 hours.
#         </div>
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <div class="header_container container-fluid" id="header">
#     <div class="max-width-container">
#      <div class="layer">
#      </div>
#      <div class="sidenav" id="mySidenav">
#       <div class="ham_menu_items_container guest">
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/internships">
#           Internships
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_training_items ham_menu_items without_link">
#         <div class="ham_title ham_main_heading">
#          Online Trainings
#          <div class="contest">
#           CONTEST
#          </div>
#          <i class="ic-24-chevron-down">
#          </i>
#         </div>
#         <div class="ham_submenu_items">
#          <div class="ham_menu_training_items ham_inner_menu_items">
#           <div class="ham_inner_title">
#            Contests
#            <div class="contest">
#             ENDS SOON
#            </div>
#            <i class="ic-24-chevron-down">
#            </i>
#           </div>
#           <div class="ham_inner_submenu_items">
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/webdev-battle?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Web Development
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/marketing-ninja?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Digital Marketing
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/python-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Programming with Python
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/autocad-designer-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             AutoCAD
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/machine-learning-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Machine Learning
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/appathon?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Android App Development
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/data-science-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Data Science
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/c-c-plus-coding-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Programming with C &amp; C++
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/finance-wizard-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Financial Modeling and Valuation
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/hackathon?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Ethical Hacking
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/code-java-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Core Java
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/creative-writing-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             Creative Writing
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/solidworks-designer-challenge?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             SOLIDWORKS
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/contest/bonjour-french?utm_source=internshala-menu-dropdown-14contest__SkillFest_2ndJune21" style="" target="_blank">
#             French
#            </a>
#           </div>
#          </div>
#          <div class="ham_menu_training_items ham_inner_menu_items">
#           <div class="ham_inner_title">
#            Programming
#            <i class="ic-24-chevron-down">
#            </i>
#           </div>
#           <div class="ham_inner_submenu_items">
#            <a class="trainings_link" href="https://trainings.internshala.com/react-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             React
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/blockchain-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Blockchain
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/angular-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Angular
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/r-programming-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             R Programming
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/git-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Git &amp; GitHub
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/how-to-ace-coding-interviews-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             How to Ace Coding Interviews
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/data-structures-algorithms?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Data Structures &amp; Algorithms
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/sas-programming?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             SAS Programming
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/matlab-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             MATLAB
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/software-testing-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Software Testing
#            </a>
#           </div>
#          </div>
#          <div class="ham_menu_training_items ham_inner_menu_items">
#           <div class="ham_inner_title">
#            Business &amp; Management
#            <i class="ic-24-chevron-down">
#            </i>
#           </div>
#           <div class="ham_inner_submenu_items">
#            <a class="trainings_link" href="https://trainings.internshala.com/excel-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Advanced Excel
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/business-communication-skills-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Business Communication Skills
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/trading-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Beginner's Trading Certification
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/how-to-startup-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             How To Startup
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/tally?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Tally
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/hr?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Human Resource Management
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/sql-data-analytics-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             SQL for Data Analytics
#            </a>
#           </div>
#          </div>
#          <div class="ham_menu_training_items ham_inner_menu_items">
#           <div class="ham_inner_title">
#            Core Engineering
#            <i class="ic-24-chevron-down">
#            </i>
#           </div>
#           <div class="ham_inner_submenu_items">
#            <a class="trainings_link" href="https://trainings.internshala.com/autocad-three-d-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Autocad 3D
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/advanced-solidworks?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Advanced SOLIDWORKS
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/staad-pro-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             STAAD Pro
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/fusion-360-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Fusion 360
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/iot-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Internet of Things
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/ansys?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Ansys
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/three-d-printing?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             3D Printing
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/pcb-design?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             PCB Design
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/labview?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             LabVIEW
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/arduino?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Arduino
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/catia?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             CATIA
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/matlab-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             MATLAB
#            </a>
#           </div>
#          </div>
#          <div class="ham_menu_training_items ham_inner_menu_items">
#           <div class="ham_inner_title">
#            Data Science
#            <i class="ic-24-chevron-down">
#            </i>
#           </div>
#           <div class="ham_inner_submenu_items">
#            <a class="trainings_link" href="https://trainings.internshala.com/tableau-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Tableau
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/deep-learning?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Deep Learning
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/sas-programming?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             SAS Programming
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/statistics-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Statistics for Data Science
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/power-bi-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Power BI
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/sql-data-analytics-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             SQL for Data Analytics
#            </a>
#           </div>
#          </div>
#          <div class="ham_menu_training_items ham_inner_menu_items">
#           <div class="ham_inner_title">
#            Design
#            <i class="ic-24-chevron-down">
#            </i>
#           </div>
#           <div class="ham_inner_submenu_items">
#            <a class="trainings_link" href="https://trainings.internshala.com/graphic-design-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Graphic Design
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/ui-ux-design-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             UI/UX Design
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/video-editing-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Video Editing
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/animation-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Animation
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/wordpress?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             WordPress
#            </a>
#           </div>
#          </div>
#          <div class="ham_menu_training_items ham_inner_menu_items">
#           <div class="ham_inner_title">
#            Creative Arts
#            <i class="ic-24-chevron-down">
#            </i>
#           </div>
#           <div class="ham_inner_submenu_items">
#            <a class="trainings_link" href="https://trainings.internshala.com/guitar-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Learn Guitar in 30 days
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/photography-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Photography
#            </a>
#           </div>
#          </div>
#          <div class="ham_menu_training_items ham_inner_menu_items">
#           <div class="ham_inner_title">
#            Career Development
#            <i class="ic-24-chevron-down">
#            </i>
#           </div>
#           <div class="ham_inner_submenu_items">
#            <a class="trainings_link" href="https://trainings.internshala.com/business-communication-skills-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Business Communication Skills
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/ppt-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Internship &amp; Job Preparation
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/how-to-ace-coding-interviews-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             How to Ace Coding Interviews
#            </a>
#           </div>
#          </div>
#          <div class="ham_menu_training_items ham_inner_menu_items">
#           <div class="ham_inner_title">
#            Architecture
#            <i class="ic-24-chevron-down">
#            </i>
#           </div>
#           <div class="ham_inner_submenu_items">
#            <a class="trainings_link" href="https://trainings.internshala.com/autocad-three-d-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Autocad 3D
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/revit-training?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Revit
#            </a>
#           </div>
#          </div>
#          <div class="ham_menu_training_items ham_inner_menu_items">
#           <div class="ham_inner_title">
#            Specializations
#            <i class="ic-24-chevron-down">
#            </i>
#           </div>
#           <div class="ham_inner_submenu_items">
#            <a class="trainings_link" href="https://trainings.internshala.com/job-specialization-digital-marketing?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Digital Marketing Specialization
#            </a>
#            <a class="trainings_link" href="https://trainings.internshala.com/job-specialization-data-science?utm_source=internshala-menu-dropdown-FTUD" style="" target="_blank">
#             Data Science Specialization
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/internships/work-from-home-jobs?utm_source=wfh_mobile_hamburger">
#           WFH Internships
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/fresher-jobs">
#           Fresher Jobs
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/contact">
#           Contact Us
#          </a>
#         </div>
#        </div>
#        <hr class="ham_line_break"/>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/registration/student">
#           Register - As a Student
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_items">
#         <div class="ham_main_heading">
#          <a href="/registration/employer">
#           Register - As an Employer
#          </a>
#         </div>
#        </div>
#        <div class="ham_menu_items without_link">
#         <div class="ham_main_heading home_page_login_button" data-target="#login-modal" data-toggle="modal" id="ham_login_button">
#          Login
#         </div>
#        </div>
#       </div>
#      </div>
#      <nav class="navbar navbar-expand-md">
#       <div class="brand_container">
#        <img id="hamburger_menu_key" src="/static/images/icons/hamburger-menu-key-new.svg"/>
#        <span class="offer_hamburger_dot" id="offer_hamburger_dot">
#        </span>
#        <a class="navbar-brand" href="/">
#         <img src="/static/images/common/new_internshala_logo.svg"/>
#        </a>
#       </div>
#       <div class="collapse navbar-collapse navbar_desktop">
#        <ul class="navbar-nav nav_menu_container">
#         <li class="nav-item internship_container_hover dropdown dropdown-hover dropdown_backdrop">
#          <a class="nav-link dropdown-toggle" href="/internships" id="internships_new_superscript">
#           Internships
#           <i class="is_icon_header ic-24-filled-down-arrow">
#           </i>
#          </a>
#          <div class="dropdown-menu dropdown-menu-center menu_dropdown guest_dropdown" id="internships-dropdown">
#           <div class="dropdown-inner">
#            <div class="dropdown-inner-container">
#             <div class="inner-dropdown">
#              <div class="menu-heading">
#               Location
#              </div>
#              <ul class="dropdown-menu-part">
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/work-from-home-jobs" style="">
#                 Work from Home
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-bangalore" style="">
#                 Internship in Bangalore
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-delhi" style="">
#                 Internship in Delhi
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-hyderabad" style="">
#                 Internship in Hyderabad
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-mumbai" style="">
#                 Internship in Mumbai
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-chennai" style="">
#                 Internship in Chennai
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-pune" style="">
#                 Internship in Pune
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-kolkata" style="">
#                 Internship in Kolkata
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/internship-in-jaipur" style="">
#                 Internship in Jaipur
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/international-internship" style="">
#                 International Internship
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="inner-dropdown">
#              <div class="menu-heading">
#               Profile
#              </div>
#              <ul class="dropdown-menu-part">
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/computer%20science-internship" style="">
#                 Computer Science Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/marketing-internship" style="">
#                 Marketing Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/finance-internship" style="">
#                 Finance Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/mechanical-internship" style="">
#                 Mechanical Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/hr-internship" style="">
#                 HR Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/digital marketing-internship" style="">
#                 Digital Marketing Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/electronics-internship" style="">
#                 Electronics Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/content%20writing-internship" style="">
#                 Content Writing Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/civil-internship" style="">
#                 Civil Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/campus ambassador-internship?utm_source=header" style="">
#                 Campus Ambassador Program
#                </a>
#               </li>
#              </ul>
#             </div>
#             <div class="inner-dropdown">
#              <div class="menu-heading">
#               Category
#              </div>
#              <ul class="dropdown-menu-part">
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/engineering-internship" style="">
#                 Engineering Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/mba-internship" style="">
#                 MBA Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/part-time-jobs" style="">
#                 Part-Time Jobs/Internships
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/graphic design-internship" style="">
#                 Graphic Design Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/humanities-internship" style="">
#                 Humanities Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/science-internship" style="">
#                 Science Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/law-internship" style="">
#                 Law Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/architecture-internship" style="">
#                 Architecture Internship
#                </a>
#               </li>
#               <li class="item">
#                <a class="item_link internship_item_location" href="https://internshala.com/internships/ppo-true" style="">
#                 Internships with Job Offer
#                </a>
#               </li>
# ...
#         input_domains.push("gmain.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmiail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comn");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.ckm");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comcom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gamil.co");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.com.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmai8l.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gamil.comm");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.ckn");
#         valid_domains.push("gmail.com");
#         input_domains.push("g-mail.come");
#         valid_domains.push("gmail.com");
#         input_domains.push("gimeil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("g.mali.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comb");
#         valid_domains.push("gmail.com");
#         input_domains.push("ggmail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.combus");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comch");
#         valid_domains.push("gmail.com");
#         input_domains.push("gma2il.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gimel.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmai.lcom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.come");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmalil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comk");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmeil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.cin");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comlll");
#         valid_domains.push("gmail.com");
#         input_domains.push("gml.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comlo");
#         valid_domains.push("gmail.com");
#         input_domains.push("ghmail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.commaniraj");
#         valid_domains.push("gmail.com");
#         input_domains.push("gimal.co");
#         valid_domains.push("gmail.com");
#         input_domains.push("gamile.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaaail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comopp");
#         valid_domains.push("gmail.com");
#         input_domains.push("gemil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comp");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmajl.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.compin");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmaigmai.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comrith");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmamil.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comt");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comw");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.cam");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comy");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmial.come");
#         valid_domains.push("gmail.com");
#         input_domains.push("gani.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmile.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.cpm");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmit.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.gom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmmail.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.lcom");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.clom");
#         valid_domains.push("gmail.com");
#         input_domains.push("g.mail.co");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.om");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.co.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.v.com");
#         valid_domains.push("gmail.com");
#         input_domains.push("gamil.come");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.coma");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.coman");
#         valid_domains.push("gmail.com");
#         input_domains.push("gmail.comar");
#         valid_domains.push("gmail.com");
#     var utm_medium = "";
#     var utm_campaign = "";
#     var internship_cluster_size = 5;
#     var internship_type = "";
#     var toShowMatchingPreferences = 0;
#     var searchUIType = "new";
#     var is_ifw_partner_banner_shown = 0;
#     var scroll_from_id = 0;
#     var scroll_page_number = 2;
#     var scroll_last_page = false;
#     var employment_type = "job";
#    </script>
#    <div class="generic_footer" id="footer">
#     <div class="container-fluid">
#      <div class="max-width-container">
#       <div class="footer_container">
#        <div class="footer-column d-none d-lg-block">
#         <div class="footer-list">
#          <h5>
#           Internships by places
#          </h5>
#          <div class="footer-list-item">
#           <a href="/internships">
#            Internship in India
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/internship-in-delhi">
#            Internship in Delhi
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/internship-in-bangalore">
#            Internship in Bangalore
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/internship-in-hyderabad">
#            Internship in Hyderabad
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/internship-in-mumbai">
#            Internship in Mumbai
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/internship-in-chennai">
#            Internship in Chennai
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/internship-in-gurgaon">
#            Internship in Gurgaon
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/internship-in-kolkata">
#            Internship in Kolkata
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/work-from-home-jobs">
#            Virtual internship
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="footer-column d-none d-lg-block" id="stream-container">
#         <div class="footer-list">
#          <h5>
#           Internship by Stream
#          </h5>
#          <div class="footer-list-item">
#           <a href="/internships/computer%20science-internship">
#            Computer Science Internship
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/electronics-internship">
#            Electronics Internship
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/mechanical-internship">
#            Mechanical Internship
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/civil-internship">
#            Civil Internship
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/marketing-internship">
#            Marketing Internship
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/chemical-internship">
#            Chemical Internship
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/finance-internship">
#            Finance Internship
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/summer%20research%20fellowship-internship">
#            Summer Research Fellowship
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="/internships/campus%20ambassador-internship?utm_medium=footer">
#            Campus Ambassador Program
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="footer-column d-none d-lg-block" id="trainings-container">
#         <div class="footer-list">
#          <h5>
#           <div id="trainings-footer">
#            <a href="https://trainings.internshala.com/?utm_source=is-footer-FTUD" rel="noopener" target="_blank">
#             Online Trainings
#             <span class="offer">
#              CONTEST
#             </span>
#            </a>
#           </div>
#          </h5>
#          <div class="footer-list-item">
#           <a href="https://trainings.internshala.com/contest/webdev-battle?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">
#            Web Development
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://trainings.internshala.com/contest/appathon?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">
#            Android App Development
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://trainings.internshala.com/contest/python-challenge?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">
#            Programming with Python
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://trainings.internshala.com/contest/data-science-challenge?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">
#            Data Science
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://trainings.internshala.com/contest/hackathon?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">
#            Ethical Hacking
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://trainings.internshala.com/contest/code-java-challenge?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">
#            Core Java
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://trainings.internshala.com/contest/marketing-ninja?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">
#            Digital Marketing
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://trainings.internshala.com/excel-training?utm_source=is-footer-FTUD" rel="noopener" target="_blank">
#            Advanced Excel
#           </a>
#          </div>
#          <div class="footer-list-item">
#           <a href="https://trainings.internshala.com/contest/c-c-plus-coding-challenge?utm_source=is-footer-14contest__SkillFest_2ndJune21" rel="noopener" target="_blank">
#            Programming with C &amp; C++
#           </a>
#          </div>
#         </div>
#        </div>
#        <div class="footer-column" id="about-us-container">
#         <div class="footer-list">
#          <h5 class="d-none d-lg-block">
#           About Internshala
#          </h5>
#          <div id="about_internshala_left">
#           <div class="footer-list-item">
#            <a href="/about_us">
#             About us
#            </a>
#           </div>
#           <div class="footer-list-item">
#            <a href="/careers">
#             We're hiring
#            </a>
#           </div>
#           <div class="footer-list-item">
#            <a href="/registration/employer?utm_source=ISfooter">
#             Hire interns for your company
#            </a>
#           </div>
#           <div class="footer-list-item">
#            <a href="http://blog.internshala.com/internshala-editorials/team-diary/" target="_blank">
#             Team Diary
#            </a>
#           </div>
#           <div class="footer-list-item">
#            <a href="https://blog.internshala.com/?utm_source=IS_footer" target="_blank">
#             Blog
#            </a>
#           </div>
#           <div class="footer-list-item">
#            <a href="/products_services">
#             Our Services
#            </a>
#           </div>
#          </div>
#          <div id="about_internshala_right">
#           <div class="footer-list-item">
#            <a href="/terms">
#             Terms &amp; Conditions
#            </a>
#           </div>
#           <div class="footer-list-item">
#            <a href="/privacy">
#             Privacy
#            </a>
#           </div>
#           <div class="footer-list-item">
#            <a href="/contact">
#             Contact us
#            </a>
#           </div>
#          </div>
#         </div>
#        </div>
#       </div>
#       <div id="footer-bottom">
#        <a href="https://play.google.com/store/apps/details?id=com.internshala.app&amp;referrer=utm_source%3Dplay_footer" target="_blank">
#         <div class="footer-list-item" id="android_app_container">
#          <i class="ic-24-playstore">
#          </i>
#          <span>
#           Get Android App
#          </span>
#         </div>
#        </a>
#        <div id="social_media_container">
#         <a class="social_media_link_footer" href="https://www.instagram.com/internshala/?utm_source=IS_footer" target="_blank">
#          <i class="ic-24-instagram">
#          </i>
#         </a>
#         <a class="social_media_link_footer" href="https://twitter.com/Internshala?utm_source=IS_footer" target="_blank">
#          <i class="ic-24-twitter">
#          </i>
#         </a>
#         <a class="social_media_link_footer" href="https://www.youtube.com/c/internshalaofficial?utm_source=IS_footer" target="_blank">
#          <img class="img-icon" src="/static/images/common/yt_icon_mono_dark.png"/>
#         </a>
#         <a class="social_media_link_footer" href="https://www.linkedin.com/company/internshala/?utm_source=is-footer" target="_blank">
#          <i class="ic-24-linkedin">
#          </i>
#         </a>
#        </div>
#        <div class="" id="copyright">
#         © Copyright 2021 Internshala
#        </div>
#        <div class="clear">
#        </div>
#       </div>
#      </div>
#     </div>
#    </div>
#    <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#     var big_brand = 'yes';
#    </script>
#   </div>
#   <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#    /* <![CDATA[ */
#     var google_conversion_id = 981478532;
#     var google_custom_params = window.google_tag_params;
#     var google_remarketing_only = true;
#     /* ]]> */
#   </script>
#   <script src="https://www.googleadservices.com/pagead/conversion.js" type="text/javascript">
#   </script>
#   <noscript>
#    <div style="display:inline;">
#     <img alt="" height="1" src="https://googleads.g.doubleclick.net/pagead/viewthroughconversion/981478532/?value=0&amp;guid=ON&amp;script=0" style="border-style:none;" width="1"/>
#    </div>
#   </noscript>
#  </body>
#  <script nonce="Up0jQC7oJZMA39Jw1bBGuA==">
#   if (new_design_system) {
#             setTimeout(function () {
#                 var loading_toast = document.getElementById("loading_toast");
#                 if (typeof loading_toast !== 'undefined' && loading_toast) {
#                     loading_toast.style.display = "block";
#                 }
#             }, 2000);
#         }
#  </script>
# </html>

# %%
first_title=soup.find('div',class_="heading_4_5 profile")
first_title
# Out:
# <div class="heading_4_5 profile">
# <a href="/fresher-job/detail/remote-react-native-developer-fresher-jobs-at-runners-planet1622653252">React Native Developer</a> </div>

# %%
first_title.text
# Out:
# '\nReact Native Developer '

# %%
first_title.text.replace('\n','')
# Out:
# 'React Native Developer '

# %%
first_company=soup.find('a',class_="link_display_like_text")
first_company
# Out:
# <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Runners%20Planet">
#                         Runners Planet                    </a>

# %%
first_company.text
# Out:
# '\n                        Runners Planet                    '

# %%
first_company.text.replace('\n','')
# Out:
# '                        Runners Planet                    '

# %%
first_location=soup.find('a',class_="location_link")
first_location
# Out:
# <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>

# %%
first_location.text.replace('\n','')
# Out:
# 'Remote'

# %%
titles=soup.find_all('div',class_="heading_4_5 profile")
titles
# Out:
# [<div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-react-native-developer-fresher-jobs-at-runners-planet1622653252">React Native Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/research-and-communications-associate-fresher-jobs-in-delhi-at-institute-for-governance-policies-politics1622532413">Research And Communications Associate</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-data-scientist-fresher-jobs-at-protonautoml1622608045">Data Scientist</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-data-science-django-developer-fresher-jobs-at-markytics1622609332">Data Science Django Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/corporate-sales-associate-fresher-jobs-in-delhi-at-mim-essay1622609018">Corporate Sales Associate</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-full-stack-developer-fresher-jobs-at-wondermail1622540594">Full Stack Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/full-stack-developer-mern-fresher-jobs-in-multiple-locations-at-project-tinker1622540579">Full Stack Developer (MERN)</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-business-development-executive-fresher-jobs-at-kaizen-academy1622362312">Business Development Executive</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/sales-development-representative-fresher-jobs-in-bangalore-at-amigobulls1622526229">Sales Development Representative</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/graphic-designer-fresher-jobs-in-ahmedabad-at-underground-movement-llp1622460539">Graphic Designer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/operations-executive-fresher-jobs-in-mumbai-at-alphacore-technologies-private-limited1622515573">Operations Executive</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-business-development-executive-fresher-jobs-at-ruhcom-enterprises-private-limited1622282544">Business Development Executive</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/admission-counselor-sales-fresher-jobs-in-multiple-locations-at-sky-education-group1622460078">Admission Counselor (Sales)</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/sales-and-business-development-analyst-fresher-jobs-in-delhi-at-mos-f-b-group1622455308">Sales And Business Development Analyst</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/growth-hacking-digital-marketer-fresher-jobs-in-hyderabad-at-sleep-love1622203678">Growth Hacking Digital Marketer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/junior-nodejs-developer-fresher-jobs-in-multiple-locations-at-askadmissionsai1622448515">Junior Node.js Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/junior-digital-marketing-executive-fresher-jobs-in-ahmedabad-at-krivy1622366960">Junior Digital Marketing Executive</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/ios-app-developer-fresher-jobs-in-kolkata-at-ascentspark-software-private-limited1622357936">iOS App Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/food-journalist-fresher-jobs-in-delhi-at-truffle-nation1622274188">Food Journalist</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/junior-software-developer-fresher-jobs-in-chennai-at-habitate-technologies-private-limited1622441329">Junior Software Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-full-stack-developer-fresher-jobs-at-solulab1622265179">Full Stack Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-business-analyst-fresher-jobs-at-solulab1622265661">Business Analyst</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/associate-full-stack-developer-fresher-jobs-in-multiple-locations-at-repozitory-technologies-private-limited1622177877">Associate Full Stack Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-full-stack-engineer-fresher-jobs-at-beehive-academy-india1622264703">Full Stack Engineer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-product-marketer-fresher-jobs-at-bip1622196057">Product Marketer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-business-development-executive-fresher-jobs-at-tabeazy1622128145">Business Development Executive</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/associate-business-development-fresher-jobs-in-delhi-at-leverage-edu1622099575">Associate - Business Development</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/research-analyst-economics-fresher-jobs-in-delhi-at-dex-deft-research-and-consulting-opc-private-limited1622183094">Research Analyst (Economics)</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/machine-learning-engineer-fresher-jobs-in-bangalore-at-aimonk-labs-technology-limited1622016591">Machine Learning Engineer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/business-analyst-fresher-jobs-in-gurgaon-at-kasper-consulting-private-limited1622086281">Business Analyst</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-business-development-executive-inside-sales-fresher-jobs-at-greedge1622030663">Business Development Executive (Inside Sales)</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/business-development-associate-fresher-jobs-in-bangalore-at-pepkidz-learning1622025801">Business Development Associate</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/full-stack-software-engineer-fresher-jobs-in-mumbai-at-flair-labs1621057665">Full Stack Software Engineer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-associate-front-end-developer-fresher-jobs-at-little-big-things1622013372">Associate Front End Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-talent-acquisition-executive-fresher-jobs-at-crewkarma1621940075">Talent Acquisition Executive</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-full-stack-developer-fresher-jobs-at-codfirm1621876995">Full Stack Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-backend-developer-fresher-jobs-at-webmobi1621878268">Backend Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/full-stack-developer-fresher-jobs-in-multiple-locations-at-tmbill-software1621861934">Full Stack Developer</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/remote-junior-sales-associate-fresher-jobs-at-kraftshala1621247053">Junior Sales Associate</a> </div>,
#  <div class="heading_4_5 profile">
#  <a href="/fresher-job/detail/digital-marketing-specialist-fresher-jobs-in-mumbai-at-black-jack1621782569">Digital Marketing Specialist</a> </div>]

# %%
job_titles=[]
for i in titles:
    job_titles.append(i.text)
job_titles
# Out:
# ['\nReact Native Developer ',
#  '\nResearch And Communications Associate ',
#  '\nData Scientist ',
#  '\nData Science Django Developer ',
#  '\nCorporate Sales Associate ',
#  '\nFull Stack Developer ',
#  '\nFull Stack Developer (MERN) ',
#  '\nBusiness Development Executive ',
#  '\nSales Development Representative ',
#  '\nGraphic Designer ',
#  '\nOperations Executive ',
#  '\nBusiness Development Executive ',
#  '\nAdmission Counselor (Sales) ',
#  '\nSales And Business Development Analyst ',
#  '\nGrowth Hacking Digital Marketer ',
#  '\nJunior Node.js Developer ',
#  '\nJunior Digital Marketing Executive ',
#  '\niOS App Developer ',
#  '\nFood Journalist ',
#  '\nJunior Software Developer ',
#  '\nFull Stack Developer ',
#  '\nBusiness Analyst ',
#  '\nAssociate Full Stack Developer ',
#  '\nFull Stack Engineer ',
#  '\nProduct Marketer ',
#  '\nBusiness Development Executive ',
#  '\nAssociate - Business Development ',
#  '\nResearch Analyst (Economics) ',
#  '\nMachine Learning Engineer ',
#  '\nBusiness Analyst ',
#  '\nBusiness Development Executive (Inside Sales) ',
#  '\nBusiness Development Associate ',
#  '\nFull Stack Software Engineer ',
#  '\nAssociate Front End Developer ',
#  '\nTalent Acquisition Executive ',
#  '\nFull Stack Developer ',
#  '\nBackend Developer ',
#  '\nFull Stack Developer ',
#  '\nJunior Sales Associate ',
#  '\nDigital Marketing Specialist ']

# %%
len(job_titles)
# Out:
# 40

# %%
companies=soup.find_all('a',class_="link_display_like_text")
companies
# Out:
# [<a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Runners%20Planet">
#                          Runners Planet                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Institute%20For%20Governance%2C%20Policies%20%26%20Politics">
#                          Institute For Governance, Policies &amp; Politics                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-ProtonAutoML">
#                          ProtonAutoML                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Markytics">
#                          Markytics                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-MiM-Essay">
#                          MiM-Essay                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Wondermail">
#                          Wondermail                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Project%20Tinker">
#                          Project Tinker                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Kaizen%20Academy">
#                          Kaizen Academy                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Amigobulls">
#                          Amigobulls                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Underground%20Movement%20LLP">
#                          Underground Movement LLP                    </a>,
#                          Flair Labs                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Little%20Big%20Things">
#                          Little Big Things                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-CrewKarma">
#                          CrewKarma                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Codfirm">
#                          Codfirm                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-WebMOBI">
#                          WebMOBI                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-TMBill%20Software">
#                          TMBill Software                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Kraftshala">
#                          Kraftshala                    </a>,
#  <a class="link_display_like_text" href="/fresher-jobs/fresher-job-at-Black%20Jack">
#                          Black Jack                    </a>]

# %%
company_names = []
for i in companies:
    company_names.append(i.text.replace("\n",""))
company_names
# Out:
# ['                        Runners Planet                    ',
#  '                        Institute For Governance, Policies & Politics                    ',
#  '                        ProtonAutoML                    ',
#  '                        Markytics                    ',
#  '                        MiM-Essay                    ',
#  '                        Wondermail                    ',
#  '                        Project Tinker                    ',
#  '                        Kaizen Academy                    ',
#  '                        Amigobulls                    ',
#  '                        Underground Movement LLP                    ',
#  '                        Alphacore Technologies Private Limited                    ',
#  '                        Ruhcom Enterprises Private Limited                    ',
#  '                        Sky Education Group                    ',
#  "                        Mo's F&B Group                    ",
#  '                        Sleep Love                    ',
#  '                        Askadmissions.ai                    ',
#  '                        Krivy                    ',
#  '                        Ascentspark Software Private Limited                    ',
#  '                        Truffle Nation                    ',
#  '                        Habitate Technologies Private Limited                    ',
#  '                        SoluLab                    ',
#  '                        SoluLab                    ',
#  '                        REPOZITORY TECHNOLOGIES PRIVATE LIMITED                    ',
#  '                        Beehive Academy India                    ',
#  '                        Bip                    ',
#  '                        Tabeazy                    ',
#  '                        Leverage Edu                    ',
#  '                        DEX-DEFT Research And Consulting OPC Private Limited                    ',
#  '                        AIMonk Labs Technology Limited                    ',
#  '                        Kasper Consulting Private Limited                    ',
#  '                        GREedge                    ',
#  '                        PEPKIDZ LEARNING                    ',
#  '                        Flair Labs                    ',
#  '                        Little Big Things                    ',
#  '                        CrewKarma                    ',
#  '                        Codfirm                    ',
#  '                        WebMOBI                    ',
#  '                        TMBill Software                    ',
#  '                        Kraftshala                    ',
#  '                        Black Jack                    ']

# %%
location=soup.find_all('a',class_="location_link")
location
# Out:
# [<a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-delhi">Delhi</a>,
#  <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-delhi">Delhi</a>,
#  <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-ahmedabad">Ahmedabad</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-gurgaon">Gurgaon</a>,
#  <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-delhi">Delhi</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-delhi">Delhi</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-bangalore">Bangalore</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-gurgaon">Gurgaon</a>,
#  <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-bangalore">Bangalore</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-mumbai">Mumbai</a>,
#  <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-pune">Pune</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-aurangabad">Aurangabad</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-sangli">Sangli</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-ahmednagar">Ahmednagar</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-satara">Satara</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-navi mumbai">Navi Mumbai</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-mumbai">Mumbai</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-nashik">Nashik</a>,
#  <a class="location_link" href="/fresher-jobs/remote_jobs">Remote</a>,
#  <a class="location_link" href="/fresher-jobs/jobs-in-mumbai">Mumbai</a>]

# %%
location_names = []
for i in location:
    location_names.append(i.text.replace("\n",""))
location_names
# Out:
# ['Remote',
#  'Delhi',
#  'Remote',
#  'Remote',
#  'Delhi',
#  'Remote',
#  'Ahmedabad',
#  'Gurgaon',
#  'Kolkata',
#  'Pune',
#  'Bangalore',
#  'Mumbai',
#  'Remote',
#  'Bangalore',
#  'Ahmedabad',
#  'Mumbai',
#  'Remote',
#  'Delhi',
#  'Ghaziabad',
#  'Noida',
#  'Delhi',
#  'Hyderabad',
#  'Chennai',
#  'Bangalore',
#  'Hyderabad',
#  'Mumbai',
#  'Cochin',
#  'Ahmedabad',
#  'Kolkata',
#  'Delhi',
#  'Chennai',
#  'Remote',
#  'Remote',
#  'Abohar',
#  'Kaithal',
#  'Jind',
#  'Karnal',
#  'Kurukshetra',
#  'Sirsa',
#  'Yamuna Nagar',
#  'Churu',
#  'Hisar',
#  'Bhiwani',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Delhi',
#  'Delhi',
#  'Bangalore',
#  'Gurgaon',
#  'Remote',
#  'Bangalore',
#  'Mumbai',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Remote',
#  'Pune',
#  'Aurangabad',
#  'Sangli',
#  'Ahmednagar',
#  'Satara',
#  'Navi Mumbai',
#  'Mumbai',
#  'Nashik',
#  'Remote',
#  'Mumbai']
